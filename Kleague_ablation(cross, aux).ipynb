# %% [markdown]
# # Final Model V2.4 - Cross-Attention Fusion (Spatial-Temporal)
#
# - **Base**: `Final_env_v2_3.ipynb` (Gated Fusion Success)
# - **Improvement**: **Cross-Attention Fusion**
# - **Concept**:
#     - GRU provides the **Intent** (Query) -> "Player turning left"
#     - CNN provides the **Spatial Map** (Key/Value) -> "Open space at (x,y)"
#     - **Cross-Attention**: The model dynamically attends to specific spatial regions based on the player's movement intent.
# - **Preprocessor**: `Preprocessing_final_v2` (Pure Physics, No Angle)

# %%
import os
import random
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence, pad_sequence
from sklearn.model_selection import GroupKFold
import cv2 
from tqdm import tqdm
import joblib
import json

# [Same Preprocessor as V2.3]
from Preprocessing_final_v2_fixed import FootballPreprocessorMultimodal

FOLD_SEEDS = {
    1: 42, 2: 43, 3: 44, 4: 45, 5: 46,
    6: 47, 7: 48, 8: 49, 9: 50, 10: 51,
}

def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device: {DEVICE}")
# Out:
# Device: cuda

# %% [markdown]
# ## 1. 데이터 로드 및 전처리 (V2.3 동일)

# %%
DATA_DIR = './data'
train_df = pd.read_csv(os.path.join(DATA_DIR, "train.csv"))
print(f"Loaded {len(train_df)} rows")
# Out:
# Loaded 356721 rows

# %%
# Dataset Code - Identical to V2.3
class MultiModalDataset(Dataset):
    def __init__(self, episodes, img_size=(68, 105), augment=False, cache_images=True):
        self.episodes = episodes
        self.H, self.W = img_size
        self.augment = augment
        self.cache_images = cache_images
        self.img_cache = None
        
        if self.cache_images:
            print(f"Pre-rendering {len(episodes)} images (Cache Enabled)...")
            self.img_cache = [self._generate_image(ep['cont']) for ep in tqdm(episodes, desc="Caching Images")]

    def __len__(self):
        return len(self.episodes)

    def _generate_image(self, cont_data):
        img_np = np.zeros((2, self.H, self.W), dtype=np.float32)
        if len(cont_data) == 0:
             return torch.tensor(img_np, dtype=torch.float32)

        seq_len = cont_data.shape[0]
        xs = cont_data[:, 0]
        ys = cont_data[:, 1]
        
        x_idxs = (xs * (self.W - 1)).round().astype(int).clip(0, self.W - 1)
        y_idxs = (ys * (self.H - 1)).round().astype(int).clip(0, self.H - 1)
        
        for t in range(seq_len):
            px, py = x_idxs[t], y_idxs[t]
            img_np[0, py, px] = 1.0
            decay_val = (t + 1) / seq_len
            if t > 0:
                prev_px, prev_py = x_idxs[t-1], y_idxs[t-1]
                cv2.line(img_np[1], (prev_px, prev_py), (px, py), color=decay_val, thickness=1)
            else:
                img_np[1, py, px] = decay_val
        return torch.tensor(img_np, dtype=torch.float32)

    def __getitem__(self, idx):
        data = self.episodes[idx]
        cont = data['cont'].copy()
        target = data['target'].copy()
        
        if self.augment and random.random() < 0.5:
            cont[:, 1] = 1.0 - cont[:, 1] # start_y
            cont[:, 3] = 1.0 - cont[:, 3] # end_y_prev
            cont[:, 5] = -cont[:, 5]      # dy_prev
            target[1] = 1.0 - target[1]
            if self.cache_images:
                base_img = self.img_cache[idx]
                img = torch.flip(base_img, [1])
            else:
                img = self._generate_image(cont)
        else:
            if self.cache_images:
                img = self.img_cache[idx]
            else:
                img = self._generate_image(cont)
        
        cont_tensor = torch.tensor(cont, dtype=torch.float32)
        cat_tensor = torch.tensor(data['cat'], dtype=torch.long)
        target_tensor = torch.tensor(target, dtype=torch.float32)
        
        seq_len = cont.shape[0]
        aux_target = np.zeros((seq_len, 2), dtype=np.float32)
        if seq_len > 1:
            aux_target[:-1] = cont[1:, 0:2]
        aux_target[-1] = target
        aux_target_tensor = torch.tensor(aux_target, dtype=torch.float32)
        
        return img, cont_tensor, cat_tensor, target_tensor, aux_target_tensor

# %% [markdown]
# ## 2. 모델 아키텍처 (Cross-Attention Fusion)
# - **SpatialCNN**: `(128, 17, 26)` Map 반환
# - **CrossAttention**: GRU Query -> CNN Map
# - **GatedFusion**: GRU + Attended Context 결합

# %%
# [Helper] Self-Attention for CNN Refining
class SpatialAttention(nn.Module):
    def __init__(self, kernel_size=7):
        super(SpatialAttention, self).__init__()
        self.conv = nn.Conv2d(2, 1, kernel_size=kernel_size, padding=kernel_size//2, bias=False)
        self.sigmoid = nn.Sigmoid()
    def forward(self, x):
        avg_out = torch.mean(x, dim=1, keepdim=True)
        max_out, _ = torch.max(x, dim=1, keepdim=True)
        x_cat = torch.cat([avg_out, max_out], dim=1)
        x_out = self.conv(x_cat)
        return self.sigmoid(x_out)

# [Modified] SpatialCNN (Retains Spatial Dimensions)
class SpatialCNN(nn.Module):
    def __init__(self):
        super(SpatialCNN, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(2, 32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.BatchNorm2d(64), nn.ReLU(), nn.MaxPool2d(2),
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128), nn.ReLU(),
        )
        self.sa = SpatialAttention()
        # No Pooling, No FC. Returns Feature Map directly.
        
    def forward(self, x):
        x = self.features(x)
        sa_map = self.sa(x)
        return x * sa_map # Shape: [B, 128, H/4, W/4]

class LSTMAttention(nn.Module):
    def __init__(self, hidden_dim):
        super(LSTMAttention, self).__init__()
        self.attention = nn.Linear(hidden_dim, 1)
    def forward(self, rnn_output):
        attn_weights = torch.softmax(self.attention(rnn_output), dim=1)
        return torch.sum(attn_weights * rnn_output, dim=1)

# [New] Cross Attention Module
class CrossAttention(nn.Module):
    def __init__(self, query_dim, key_dim, hidden_dim):
        super().__init__()
        self.query_proj = nn.Linear(query_dim, hidden_dim)
        self.key_proj = nn.Linear(key_dim, hidden_dim)
        self.value_proj = nn.Linear(key_dim, hidden_dim)
        self.scale = torch.sqrt(torch.tensor(hidden_dim, dtype=torch.float32))
        
    def forward(self, query, key_map):
        # query: [B, Q_Dim] (GRU State)
        # key_map: [B, K_Dim, H, W] (CNN Feature Map)
        
        B, C, H, W = key_map.shape
        # Flatten Key/Value: [B, H*W, C]
        flat_keys = key_map.view(B, C, -1).permute(0, 2, 1) 
        
        Q = self.query_proj(query).unsqueeze(1) # [B, 1, H_dim]
        K = self.key_proj(flat_keys)            # [B, H*W, H_dim]
        V = self.value_proj(flat_keys)          # [B, H*W, H_dim]
        
        # Attention Scores
        scores = torch.bmm(Q, K.transpose(1, 2)) / self.scale.to(query.device) # [B, 1, H*W]
        attn_weights = F.softmax(scores, dim=-1)
        
        # Context Vector
        context = torch.bmm(attn_weights, V) # [B, 1, H_dim]
        return context.squeeze(1)

# [Recycle] Gated Fusion (Same as V2.3)
class GatedFusion(nn.Module):
    def __init__(self, dim=128):
        super().__init__()
        self.gate_net = nn.Sequential(
            nn.Linear(dim * 2, dim),
            nn.Sigmoid()
        )
    def forward(self, feat1, feat2):
        concat = torch.cat([feat1, feat2], dim=1)
        z = self.gate_net(concat)
        fused = z * feat1 + (1 - z) * feat2
        return fused

class MultiModalNetV8(nn.Module):
    def __init__(self, input_dim_cont, num_types, num_results, gru_hidden=96):
        super(MultiModalNetV8, self).__init__()
        # 1. Spatial CNN
        self.cnn = SpatialCNN() # Output: [B, 128, H, W]
        
        # 2. Sequential Embeddings
        self.type_emb = nn.Embedding(num_types, 8)
        self.result_emb = nn.Embedding(num_results, 8)
        total_input_dim = input_dim_cont + 8 + 8
        
        # 3. GRU (Split)
        self.gru_hidden = gru_hidden
        self.gru_fwd = nn.GRU(total_input_dim, gru_hidden, 2, batch_first=True, dropout=0.1)
        self.gru_bwd = nn.GRU(total_input_dim, gru_hidden, 2, batch_first=True, dropout=0.1)
        self.gru_attn = LSTMAttention(gru_hidden * 2)
        self.gru_fc = nn.Linear(gru_hidden * 2, 128)
        
        self.aux_fc = nn.Linear(gru_hidden, 2) 
        
        # 4. [NEW] Cross Attention
        # Query: GRU (128), Key: CNN (128)
        self.cross_attn = CrossAttention(query_dim=128, key_dim=128, hidden_dim=128)
        
        # 5. [Recycle] Gated Fusion
        # Fuse (Original GRU) + (Context-Aware Spatial Feature)
        self.gated_fusion = GatedFusion(dim=128)
        
        # 6. Final Head
        self.final_fc = nn.Sequential(
            nn.BatchNorm1d(128),
            nn.Dropout(0.3),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 2)
        )

    def forward(self, img, cont, cat, lengths):
        # CNN (Spatial Map)
        cnn_map = self.cnn(img) # [B, 128, 17, 26]
        
        # Embeddings
        emb_type = self.type_emb(cat[:, :, 0])
        emb_result = self.result_emb(cat[:, :, 1])
        x_seq = torch.cat([cont, emb_type, emb_result], dim=2)
        
        # GRU Forward/Backward
        packed_fwd = pack_padded_sequence(x_seq, lengths.cpu(), batch_first=True, enforce_sorted=False)
        out_fwd_packed, _ = self.gru_fwd(packed_fwd)
        out_fwd, _ = pad_packed_sequence(out_fwd_packed, batch_first=True)
        
        x_seq_bwd = x_seq.clone()
        for i, length in enumerate(lengths):
            x_seq_bwd[i, :length] = x_seq[i, :length].flip(0)
        packed_bwd = pack_padded_sequence(x_seq_bwd, lengths.cpu(), batch_first=True, enforce_sorted=False)
        out_bwd_packed, _ = self.gru_bwd(packed_bwd)
        out_bwd, _ = pad_packed_sequence(out_bwd_packed, batch_first=True)
        for i, length in enumerate(lengths):
            out_bwd[i, :length] = out_bwd[i, :length].flip(0)
            
        # GRU Feature
        gru_out_combined = torch.cat([out_fwd, out_bwd], dim=2)
        gru_ctx = self.gru_attn(gru_out_combined)
        seq_feat = F.relu(self.gru_fc(gru_ctx)) # [B, 128] (Intent)
        
        # [Cross-Attention Step]
        # Query: seq_feat (Intent)
        # Key/Value: cnn_map (Opportunity)
        context_feat = self.cross_attn(seq_feat, cnn_map) # [B, 128] (Relevant Space)
        
        # [Fusion Step]
        # Fuse Intent + Opportunity
        fused = self.gated_fusion(seq_feat, context_feat)
        
        final_out = self.final_fc(fused)
        aux_out = self.aux_fc(out_fwd)
        
        return final_out, aux_out

# Losses (Same)
class EuclideanLoss(nn.Module):
    def __init__(self):
        super(EuclideanLoss, self).__init__()
    def forward(self, pred, target):
        pred_real = pred * torch.tensor([105.0, 68.0], device=pred.device)
        target_real = target * torch.tensor([105.0, 68.0], device=target.device)
        return torch.mean(torch.sqrt(torch.sum((pred_real - target_real)**2, dim=1) + 1e-6))
        
class MaskedSeqEuclideanLoss(nn.Module):
    def __init__(self):
        super(MaskedSeqEuclideanLoss, self).__init__()
    def forward(self, pred, target, lengths):
        mask = torch.arange(pred.size(1), device=pred.device)[None, :] < lengths[:, None]
        mask = mask.unsqueeze(-1)
        pred_real = pred * torch.tensor([105.0, 68.0], device=pred.device)
        target_real = target * torch.tensor([105.0, 68.0], device=target.device)
        diff = pred_real - target_real
        dist = torch.sqrt(torch.sum(diff**2, dim=2) + 1e-6)
        dist = dist * mask.squeeze(-1)
        return dist.sum() / mask.sum()

# %% [markdown]
# ## 3. 학습
# - Models and Preprocessors saved in `models_final_v2_4/`

# %%
def multimodal_collate_fn(batch):
    imgs, conts, cats, targets, aux_targets = zip(*batch)
    imgs_batched = torch.stack(imgs, dim=0)
    lengths = torch.tensor([len(c) for c in conts], dtype=torch.long)
    conts_padded = pad_sequence(conts, batch_first=True)
    cats_padded = pad_sequence(cats, batch_first=True)
    targets = torch.stack(targets, dim=0)
    aux_targets_padded = pad_sequence(aux_targets, batch_first=True)
    return imgs_batched, conts_padded, cats_padded, lengths, targets, aux_targets_padded

def train_multimodal_v2_4(train_df, n_splits=10, epochs=100, batch_size=64, lr=0.001):
    gkf = GroupKFold(n_splits=n_splits)
    groups = train_df['game_id'] 
    
    fold_scores = []

    input_dim_cont = None
    num_types = None
    num_results = None
    
    for fold, (train_idx, val_idx) in enumerate(gkf.split(train_df, groups=groups)):
        fold_seed = FOLD_SEEDS[(fold % 10) + 1]
        seed_everything(fold_seed)
        print(f"[Fold {fold+1}] Seed fixed to {fold_seed}")
        print(f"\n=== Fold {fold+1}/{n_splits} ===")
        
        train_sub_df = train_df.iloc[train_idx].copy()
        val_sub_df = train_df.iloc[val_idx].copy()
        
        preprocessor = FootballPreprocessorMultimodal()
        preprocessor.fit(train_sub_df)

        if input_dim_cont is None:
            input_dim_cont = preprocessor.get_input_dim()
            num_types, num_results = preprocessor.get_num_classes()
            print(f"Model Dimensions: input={input_dim_cont}, types={num_types}, results={num_results}")
        
        train_episodes = preprocessor.transform(train_sub_df, is_train=True)
        val_episodes = preprocessor.transform(val_sub_df, is_train=True)
        
        train_dataset = MultiModalDataset(train_episodes, augment=True, cache_images=True)
        val_dataset = MultiModalDataset(val_episodes, augment=False, cache_images=True)
        
        train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True, collate_fn=multimodal_collate_fn, drop_last=True)
        val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, collate_fn=multimodal_collate_fn)
        
        # [V2.4 Model]
        model = MultiModalNetV8(input_dim_cont, num_types, num_results).to(DEVICE)
        
        criterion_main = EuclideanLoss()
        criterion_aux = MaskedSeqEuclideanLoss() 
        
        optimizer = optim.Adam(model.parameters(), lr=lr) 
        scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3)
        
        best_dist = float('inf')
        best_state = None
        patience_counter = 0
        patience_limit = 15
        
        if not os.path.exists('models_final_v2_4'):
            os.makedirs('models_final_v2_4')
            
        for epoch in range(epochs):
            model.train()
            train_loss = 0
            for batch in train_loader:
                imgs, cont, cat, lengths, target, aux_target = batch
                imgs, cont, cat, lengths, target, aux_target = imgs.to(DEVICE), cont.to(DEVICE), cat.to(DEVICE), lengths.to(DEVICE), target.to(DEVICE), aux_target.to(DEVICE)
                
                optimizer.zero_grad()
                pred, aux_pred = model(imgs, cont, cat, lengths)
                
                loss_m = criterion_main(pred, target)
                loss_a = criterion_aux(aux_pred, aux_target, lengths)
                
                loss = loss_m + 0.5 * loss_a
                loss.backward()
                optimizer.step()
                train_loss += loss.item()
            
            train_loss /= len(train_loader)
            
            model.eval()
            val_dists = []
            with torch.no_grad():
                for batch in val_loader:
                    imgs, cont, cat, lengths, target, aux_target = batch
                    imgs, cont, cat, lengths, target, aux_target = imgs.to(DEVICE), cont.to(DEVICE), cat.to(DEVICE), lengths.to(DEVICE), target.to(DEVICE), aux_target.to(DEVICE)
                    
                    pred, _ = model(imgs, cont, cat, lengths)
                    
                    pred_real = pred.cpu().numpy() * np.array([105.0, 68.0])
                    target_real = target.cpu().numpy() * np.array([105.0, 68.0])
                    val_dists.extend(np.sqrt(np.sum((pred_real - target_real)**2, axis=1)))
            
            mean_dist = np.mean(val_dists)
            scheduler.step(mean_dist)
            print(f"Epoch {epoch+1}: Train Loss {train_loss:.4f}, Val Dist {mean_dist:.4f}")
            
            if mean_dist < best_dist:
                best_dist = mean_dist
                best_state = model.state_dict()
                torch.save(best_state, f"models_final_v2_4/multimodal_v2_4_{fold+1}.pth")
                joblib.dump(preprocessor, f"models_final_v2_4/preprocessor_v2_4_{fold+1}.pkl")
                print(f"  -> Saved Best Model (Dist: {best_dist:.4f})")
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter >= patience_limit:
                    print("Early Stopping")
                    break
        
        print(f"Fold {fold+1} Finished. Best Valid Dist: {best_dist:.4f}")
        fold_scores.append(best_dist)
    
    with open('scores_v2_4.json', 'w') as f:
        json.dump(fold_scores, f)
        
    print(f"Average Score: {np.mean(fold_scores):.4f}")

train_multimodal_v2_4(train_df)
# Out:
# [Fold 1] Seed fixed to 42
#
# === Fold 1/10 ===
# Model Dimensions: input=10, types=27, results=21
# Pre-rendering 13827 images (Cache Enabled)...
# Caching Images: 100%|██████████| 13827/13827 [00:00<00:00, 15082.98it/s]
# Pre-rendering 1601 images (Cache Enabled)...
# Caching Images: 100%|██████████| 1601/1601 [00:00<00:00, 13143.53it/s]
# Epoch 1: Train Loss 67.5922, Val Dist 20.0213
#   -> Saved Best Model (Dist: 20.0213)
# Epoch 2: Train Loss 49.2152, Val Dist 17.6512
#   -> Saved Best Model (Dist: 17.6512)
# Epoch 3: Train Loss 46.4806, Val Dist 17.5744
#   -> Saved Best Model (Dist: 17.5744)
# Epoch 4: Train Loss 45.1491, Val Dist 16.1735
#   -> Saved Best Model (Dist: 16.1735)
# Epoch 5: Train Loss 44.4278, Val Dist 16.0723
#   -> Saved Best Model (Dist: 16.0723)
# Epoch 6: Train Loss 43.4642, Val Dist 16.2663
# Epoch 7: Train Loss 42.8474, Val Dist 15.1465
#   -> Saved Best Model (Dist: 15.1465)
# Epoch 8: Train Loss 42.3665, Val Dist 15.2651
# Epoch 9: Train Loss 42.0637, Val Dist 15.1049
#   -> Saved Best Model (Dist: 15.1049)
# Epoch 10: Train Loss 41.7423, Val Dist 15.1730
# Epoch 11: Train Loss 41.3573, Val Dist 15.1699
# Epoch 12: Train Loss 41.0650, Val Dist 14.7447
#   -> Saved Best Model (Dist: 14.7447)
# Epoch 13: Train Loss 40.9742, Val Dist 14.4118
#   -> Saved Best Model (Dist: 14.4118)
# Epoch 14: Train Loss 40.6838, Val Dist 14.3386
#   -> Saved Best Model (Dist: 14.3386)
# Epoch 15: Train Loss 40.5352, Val Dist 14.3827
# Epoch 16: Train Loss 40.3396, Val Dist 14.7255
# Epoch 17: Train Loss 40.1321, Val Dist 14.1947
#   -> Saved Best Model (Dist: 14.1947)
# Epoch 18: Train Loss 39.9909, Val Dist 14.1734
#   -> Saved Best Model (Dist: 14.1734)
# Epoch 19: Train Loss 39.9069, Val Dist 14.5553
# Epoch 20: Train Loss 39.7804, Val Dist 14.2952
# Epoch 21: Train Loss 39.6081, Val Dist 14.0780
#   -> Saved Best Model (Dist: 14.0780)
# Epoch 22: Train Loss 39.5319, Val Dist 13.9090
#   -> Saved Best Model (Dist: 13.9090)
# Epoch 23: Train Loss 39.5024, Val Dist 14.1715
# Epoch 24: Train Loss 39.3695, Val Dist 14.0430
# Epoch 25: Train Loss 39.2471, Val Dist 13.9494
# Epoch 26: Train Loss 39.0426, Val Dist 14.2294
# Epoch 27: Train Loss 38.6785, Val Dist 13.6584
#   -> Saved Best Model (Dist: 13.6584)
# Epoch 28: Train Loss 38.5496, Val Dist 13.8063
# Epoch 29: Train Loss 38.4850, Val Dist 13.8007
# Epoch 30: Train Loss 38.4147, Val Dist 13.7259
# Epoch 31: Train Loss 38.3125, Val Dist 13.7398
# Epoch 32: Train Loss 38.0699, Val Dist 13.5040
#   -> Saved Best Model (Dist: 13.5040)
# Epoch 33: Train Loss 38.0566, Val Dist 13.5783
# Epoch 34: Train Loss 37.9859, Val Dist 13.6003
# Epoch 35: Train Loss 37.9173, Val Dist 13.5872
# Epoch 36: Train Loss 37.8985, Val Dist 13.5950
# Epoch 37: Train Loss 37.7824, Val Dist 13.5244
# Epoch 38: Train Loss 37.6976, Val Dist 13.5049
# Epoch 39: Train Loss 37.6982, Val Dist 13.6388
# Epoch 40: Train Loss 37.7113, Val Dist 13.5973
# Epoch 41: Train Loss 37.6216, Val Dist 13.5188
# Epoch 42: Train Loss 37.5773, Val Dist 13.5006
#   -> Saved Best Model (Dist: 13.5006)
# Epoch 43: Train Loss 37.5962, Val Dist 13.5028
# Epoch 44: Train Loss 37.5594, Val Dist 13.5863
# Epoch 45: Train Loss 37.5397, Val Dist 13.5139
# Epoch 46: Train Loss 37.5190, Val Dist 13.5382
# Epoch 47: Train Loss 37.4875, Val Dist 13.5202
# Epoch 48: Train Loss 37.4848, Val Dist 13.5341
# Epoch 49: Train Loss 37.4817, Val Dist 13.5231
# Epoch 50: Train Loss 37.4576, Val Dist 13.5276
# Epoch 51: Train Loss 37.4713, Val Dist 13.4777
#   -> Saved Best Model (Dist: 13.4777)
# Epoch 52: Train Loss 37.4360, Val Dist 13.4896
# Epoch 53: Train Loss 37.4504, Val Dist 13.4890
# Epoch 54: Train Loss 37.4710, Val Dist 13.4796
# Epoch 55: Train Loss 37.3515, Val Dist 13.5061
# Epoch 56: Train Loss 37.4553, Val Dist 13.4873
# Epoch 57: Train Loss 37.3834, Val Dist 13.5047
# Epoch 58: Train Loss 37.3922, Val Dist 13.5069
# Epoch 59: Train Loss 37.4141, Val Dist 13.4971
# Epoch 60: Train Loss 37.3499, Val Dist 13.5156
# Epoch 61: Train Loss 37.4129, Val Dist 13.5038
# Epoch 62: Train Loss 37.4293, Val Dist 13.4879
# Epoch 63: Train Loss 37.4116, Val Dist 13.5054
# Epoch 64: Train Loss 37.4339, Val Dist 13.4853
# Epoch 65: Train Loss 37.3961, Val Dist 13.5103
# Epoch 66: Train Loss 37.4478, Val Dist 13.4914
# Early Stopping
# Fold 1 Finished. Best Valid Dist: 13.4777
# [Fold 2] Seed fixed to 43
#
# === Fold 2/10 ===
# Pre-rendering 13939 images (Cache Enabled)...
# Caching Images: 100%|██████████| 13939/13939 [00:00<00:00, 16392.34it/s]
# Pre-rendering 1489 images (Cache Enabled)...
# Caching Images: 100%|██████████| 1489/1489 [00:00<00:00, 15682.14it/s]
# Epoch 1: Train Loss 66.8149, Val Dist 19.5978
#   -> Saved Best Model (Dist: 19.5978)
# Epoch 2: Train Loss 49.9820, Val Dist 18.5062
#   -> Saved Best Model (Dist: 18.5062)
# Epoch 3: Train Loss 46.9206, Val Dist 17.6569
#   -> Saved Best Model (Dist: 17.6569)
# Epoch 4: Train Loss 45.5172, Val Dist 16.6629
#   -> Saved Best Model (Dist: 16.6629)
# Epoch 5: Train Loss 44.7349, Val Dist 16.0338
#   -> Saved Best Model (Dist: 16.0338)
# Epoch 6: Train Loss 43.6851, Val Dist 15.9570
#   -> Saved Best Model (Dist: 15.9570)
# Epoch 7: Train Loss 43.2176, Val Dist 15.4663
#   -> Saved Best Model (Dist: 15.4663)
# Epoch 8: Train Loss 42.5777, Val Dist 15.5265
# Epoch 9: Train Loss 42.2183, Val Dist 14.9356
#   -> Saved Best Model (Dist: 14.9356)
# Epoch 10: Train Loss 41.9116, Val Dist 14.8705
#   -> Saved Best Model (Dist: 14.8705)
# Epoch 11: Train Loss 41.6486, Val Dist 14.6186
#   -> Saved Best Model (Dist: 14.6186)
# Epoch 12: Train Loss 41.4616, Val Dist 15.5200
# Epoch 13: Train Loss 41.1492, Val Dist 14.6733
# Epoch 14: Train Loss 40.8836, Val Dist 14.1532
#   -> Saved Best Model (Dist: 14.1532)
# Epoch 15: Train Loss 40.7558, Val Dist 14.6079
# Epoch 16: Train Loss 40.5008, Val Dist 14.2408
# Epoch 17: Train Loss 40.2432, Val Dist 14.3809
# Epoch 18: Train Loss 40.1730, Val Dist 13.9730
#   -> Saved Best Model (Dist: 13.9730)
# Epoch 19: Train Loss 40.0242, Val Dist 13.8614
#   -> Saved Best Model (Dist: 13.8614)
# Epoch 20: Train Loss 39.9125, Val Dist 14.6021
# Epoch 21: Train Loss 39.8350, Val Dist 13.8512
#   -> Saved Best Model (Dist: 13.8512)
# Epoch 22: Train Loss 39.6427, Val Dist 14.1861
# Epoch 23: Train Loss 39.4889, Val Dist 14.4361
# Epoch 24: Train Loss 39.4072, Val Dist 13.9561
# Epoch 25: Train Loss 39.3030, Val Dist 13.9236
# Epoch 26: Train Loss 38.9106, Val Dist 13.6909
#   -> Saved Best Model (Dist: 13.6909)
# Epoch 27: Train Loss 38.6830, Val Dist 13.4988
#   -> Saved Best Model (Dist: 13.4988)
# Epoch 28: Train Loss 38.5870, Val Dist 13.8193
# Epoch 29: Train Loss 38.5702, Val Dist 13.5957
# Epoch 30: Train Loss 38.4490, Val Dist 13.7043
# Epoch 31: Train Loss 38.4055, Val Dist 13.5844
# Epoch 32: Train Loss 38.1785, Val Dist 13.4345
#   -> Saved Best Model (Dist: 13.4345)
# Epoch 33: Train Loss 38.0708, Val Dist 13.4703
# Epoch 34: Train Loss 38.0195, Val Dist 13.6293
# Epoch 35: Train Loss 38.0449, Val Dist 13.6608
# Epoch 36: Train Loss 37.9768, Val Dist 13.5336
# Epoch 37: Train Loss 37.8761, Val Dist 13.4840
# Epoch 38: Train Loss 37.7832, Val Dist 13.4238
#   -> Saved Best Model (Dist: 13.4238)
# Epoch 39: Train Loss 37.7271, Val Dist 13.4354
# Epoch 40: Train Loss 37.7654, Val Dist 13.4135
#   -> Saved Best Model (Dist: 13.4135)
# Epoch 41: Train Loss 37.7135, Val Dist 13.4489
# Epoch 42: Train Loss 37.7113, Val Dist 13.3580
#   -> Saved Best Model (Dist: 13.3580)
# Epoch 43: Train Loss 37.7114, Val Dist 13.4056
# Epoch 44: Train Loss 37.6880, Val Dist 13.3777
# Epoch 45: Train Loss 37.6714, Val Dist 13.4340
# Epoch 46: Train Loss 37.6881, Val Dist 13.4005
# Epoch 47: Train Loss 37.5857, Val Dist 13.3972
# Epoch 48: Train Loss 37.4534, Val Dist 13.4179
# Epoch 49: Train Loss 37.5088, Val Dist 13.3630
# Epoch 50: Train Loss 37.5250, Val Dist 13.3832
# Epoch 51: Train Loss 37.4548, Val Dist 13.3996
# Epoch 52: Train Loss 37.4837, Val Dist 13.3709
# Epoch 53: Train Loss 37.5112, Val Dist 13.3871
# Epoch 54: Train Loss 37.3991, Val Dist 13.3632
# Epoch 55: Train Loss 37.3936, Val Dist 13.3603
# Epoch 56: Train Loss 37.4515, Val Dist 13.3486
#   -> Saved Best Model (Dist: 13.3486)
# Epoch 57: Train Loss 37.4314, Val Dist 13.3518
# Epoch 58: Train Loss 37.4531, Val Dist 13.3499
# Epoch 59: Train Loss 37.4166, Val Dist 13.3570
# Epoch 60: Train Loss 37.3725, Val Dist 13.3522
# Epoch 61: Train Loss 37.3755, Val Dist 13.3648
# Epoch 62: Train Loss 37.3830, Val Dist 13.3695
# Epoch 63: Train Loss 37.3931, Val Dist 13.3723
# Epoch 64: Train Loss 37.3940, Val Dist 13.3781
# Epoch 65: Train Loss 37.3812, Val Dist 13.3711
# Epoch 66: Train Loss 37.4033, Val Dist 13.3633
# Epoch 67: Train Loss 37.4071, Val Dist 13.3650
# Epoch 68: Train Loss 37.3598, Val Dist 13.3775
# Epoch 69: Train Loss 37.3702, Val Dist 13.3892
# Epoch 70: Train Loss 37.3948, Val Dist 13.3856
# Epoch 71: Train Loss 37.3901, Val Dist 13.3763
# Early Stopping
# Fold 2 Finished. Best Valid Dist: 13.3486
# [Fold 3] Seed fixed to 44
#
# === Fold 3/10 ===
# Pre-rendering 13878 images (Cache Enabled)...
# Caching Images: 100%|██████████| 13878/13878 [00:00<00:00, 16642.25it/s]
# Pre-rendering 1550 images (Cache Enabled)...
# Caching Images: 100%|██████████| 1550/1550 [00:00<00:00, 16249.23it/s]
# Epoch 1: Train Loss 66.2186, Val Dist 21.7621
#   -> Saved Best Model (Dist: 21.7621)
# Epoch 2: Train Loss 49.2647, Val Dist 17.5376
#   -> Saved Best Model (Dist: 17.5376)
# Epoch 3: Train Loss 46.9751, Val Dist 19.4450
# Epoch 4: Train Loss 45.4455, Val Dist 17.5240
#   -> Saved Best Model (Dist: 17.5240)
# Epoch 5: Train Loss 44.5127, Val Dist 17.3362
#   -> Saved Best Model (Dist: 17.3362)
# Epoch 6: Train Loss 43.7676, Val Dist 17.7448
# Epoch 7: Train Loss 43.0988, Val Dist 15.5624
#   -> Saved Best Model (Dist: 15.5624)
# Epoch 8: Train Loss 42.5618, Val Dist 15.2223
#   -> Saved Best Model (Dist: 15.2223)
# Epoch 9: Train Loss 42.0887, Val Dist 15.2703
# Epoch 10: Train Loss 41.8596, Val Dist 14.9733
#   -> Saved Best Model (Dist: 14.9733)
# Epoch 11: Train Loss 41.4768, Val Dist 14.7252
#   -> Saved Best Model (Dist: 14.7252)
# Epoch 12: Train Loss 41.2330, Val Dist 16.0502
# Epoch 13: Train Loss 40.9578, Val Dist 14.8633
# Epoch 14: Train Loss 40.7857, Val Dist 14.6537
#   -> Saved Best Model (Dist: 14.6537)
# Epoch 15: Train Loss 40.5379, Val Dist 14.5183
#   -> Saved Best Model (Dist: 14.5183)
# Epoch 16: Train Loss 40.3730, Val Dist 14.4606
#   -> Saved Best Model (Dist: 14.4606)
# Epoch 17: Train Loss 40.2711, Val Dist 14.4904
# Epoch 18: Train Loss 40.0294, Val Dist 14.3209
#   -> Saved Best Model (Dist: 14.3209)
# Epoch 19: Train Loss 39.8424, Val Dist 14.2639
#   -> Saved Best Model (Dist: 14.2639)
# Epoch 20: Train Loss 39.7136, Val Dist 14.3825
# Epoch 21: Train Loss 39.6179, Val Dist 14.3213
# Epoch 22: Train Loss 39.5073, Val Dist 13.9495
#   -> Saved Best Model (Dist: 13.9495)
# Epoch 23: Train Loss 39.3080, Val Dist 14.1081
# Epoch 24: Train Loss 39.3171, Val Dist 14.2628
# Epoch 25: Train Loss 39.2381, Val Dist 14.2784
# Epoch 26: Train Loss 39.1583, Val Dist 14.0572
# Epoch 27: Train Loss 38.7174, Val Dist 13.6728
#   -> Saved Best Model (Dist: 13.6728)
# Epoch 28: Train Loss 38.5399, Val Dist 13.7966
# Epoch 29: Train Loss 38.4241, Val Dist 13.6194
#   -> Saved Best Model (Dist: 13.6194)
# Epoch 30: Train Loss 38.4310, Val Dist 13.8067
# Epoch 31: Train Loss 38.2408, Val Dist 13.6563
# Epoch 32: Train Loss 38.2625, Val Dist 13.7218
# Epoch 33: Train Loss 38.2362, Val Dist 13.7209
# Epoch 34: Train Loss 37.9655, Val Dist 13.7282
# Epoch 35: Train Loss 37.9042, Val Dist 13.7500
# Epoch 36: Train Loss 37.8406, Val Dist 13.6525
# Epoch 37: Train Loss 37.7619, Val Dist 13.5416
#   -> Saved Best Model (Dist: 13.5416)
# Epoch 38: Train Loss 37.6728, Val Dist 13.5853
# Epoch 39: Train Loss 37.6629, Val Dist 13.5938
# Epoch 40: Train Loss 37.6916, Val Dist 13.7615
# Epoch 41: Train Loss 37.6445, Val Dist 13.6218
# Epoch 42: Train Loss 37.5268, Val Dist 13.5598
# Epoch 43: Train Loss 37.4346, Val Dist 13.5821
# Epoch 44: Train Loss 37.4367, Val Dist 13.5183
#   -> Saved Best Model (Dist: 13.5183)
# Epoch 45: Train Loss 37.4185, Val Dist 13.5559
# Epoch 46: Train Loss 37.3452, Val Dist 13.5544
# Epoch 47: Train Loss 37.3954, Val Dist 13.5107
#   -> Saved Best Model (Dist: 13.5107)
# Epoch 48: Train Loss 37.3304, Val Dist 13.4850
#   -> Saved Best Model (Dist: 13.4850)
# Epoch 49: Train Loss 37.3126, Val Dist 13.5526
# Epoch 50: Train Loss 37.2656, Val Dist 13.5901
# Epoch 51: Train Loss 37.2543, Val Dist 13.6233
# Epoch 52: Train Loss 37.2125, Val Dist 13.5731
# Epoch 53: Train Loss 37.1819, Val Dist 13.5718
# Epoch 54: Train Loss 37.1129, Val Dist 13.5618
# Epoch 55: Train Loss 37.1435, Val Dist 13.5955
# Epoch 56: Train Loss 37.1465, Val Dist 13.5362
# Epoch 57: Train Loss 37.0362, Val Dist 13.5207
# Epoch 58: Train Loss 37.0439, Val Dist 13.5667
# Epoch 59: Train Loss 37.0939, Val Dist 13.5426
# Epoch 60: Train Loss 37.0798, Val Dist 13.5470
# Epoch 61: Train Loss 37.0589, Val Dist 13.5494
# Epoch 62: Train Loss 37.1049, Val Dist 13.5506
# Epoch 63: Train Loss 37.0377, Val Dist 13.5611
# Early Stopping
# Fold 3 Finished. Best Valid Dist: 13.4850
# [Fold 4] Seed fixed to 45
#
# === Fold 4/10 ===
# Pre-rendering 13875 images (Cache Enabled)...
# Caching Images: 100%|██████████| 13875/13875 [00:00<00:00, 16645.43it/s]
# Pre-rendering 1553 images (Cache Enabled)...
# Caching Images: 100%|██████████| 1553/1553 [00:00<00:00, 15531.83it/s]
# Epoch 1: Train Loss 65.6529, Val Dist 20.6733
#   -> Saved Best Model (Dist: 20.6733)
# Epoch 2: Train Loss 49.1590, Val Dist 18.4356
#   -> Saved Best Model (Dist: 18.4356)
# Epoch 3: Train Loss 46.7233, Val Dist 18.4143
#   -> Saved Best Model (Dist: 18.4143)
# Epoch 4: Train Loss 45.2441, Val Dist 17.3147
#   -> Saved Best Model (Dist: 17.3147)
# Epoch 5: Train Loss 44.3851, Val Dist 16.6333
#   -> Saved Best Model (Dist: 16.6333)
# Epoch 6: Train Loss 43.6853, Val Dist 16.3800
#   -> Saved Best Model (Dist: 16.3800)
# Epoch 7: Train Loss 43.1177, Val Dist 16.4050
# Epoch 8: Train Loss 42.4537, Val Dist 15.8096
#   -> Saved Best Model (Dist: 15.8096)
# Epoch 9: Train Loss 42.0313, Val Dist 15.4642
#   -> Saved Best Model (Dist: 15.4642)
# Epoch 10: Train Loss 41.7970, Val Dist 15.8474
# Epoch 11: Train Loss 41.5352, Val Dist 15.3963
#   -> Saved Best Model (Dist: 15.3963)
# Epoch 12: Train Loss 41.2325, Val Dist 15.6905
# Epoch 13: Train Loss 41.0288, Val Dist 14.7224
#   -> Saved Best Model (Dist: 14.7224)
# Epoch 14: Train Loss 40.7777, Val Dist 14.9176
# Epoch 15: Train Loss 40.5009, Val Dist 15.7044
# Epoch 16: Train Loss 40.4168, Val Dist 14.8920
# Epoch 17: Train Loss 40.1624, Val Dist 14.9703
# Epoch 18: Train Loss 39.6633, Val Dist 14.7809
# Epoch 19: Train Loss 39.4616, Val Dist 14.2330
#   -> Saved Best Model (Dist: 14.2330)
# Epoch 20: Train Loss 39.4639, Val Dist 14.3872
# Epoch 21: Train Loss 39.3751, Val Dist 14.5066
# Epoch 22: Train Loss 39.3325, Val Dist 14.2874
# Epoch 23: Train Loss 39.2062, Val Dist 14.2270
#   -> Saved Best Model (Dist: 14.2270)
# Epoch 24: Train Loss 39.1219, Val Dist 14.2953
# Epoch 25: Train Loss 38.9990, Val Dist 14.5745
# Epoch 26: Train Loss 39.0584, Val Dist 14.3525
# Epoch 27: Train Loss 38.9048, Val Dist 14.4354
# Epoch 28: Train Loss 38.7016, Val Dist 14.0840
#   -> Saved Best Model (Dist: 14.0840)
# Epoch 29: Train Loss 38.6187, Val Dist 14.0814
#   -> Saved Best Model (Dist: 14.0814)
# Epoch 30: Train Loss 38.5752, Val Dist 14.1126
# Epoch 31: Train Loss 38.5320, Val Dist 14.0291
#   -> Saved Best Model (Dist: 14.0291)
# Epoch 32: Train Loss 38.4244, Val Dist 14.2559
# Epoch 33: Train Loss 38.4319, Val Dist 14.1615
# Epoch 34: Train Loss 38.4540, Val Dist 14.2053
# Epoch 35: Train Loss 38.3354, Val Dist 14.2305
# Epoch 36: Train Loss 38.2268, Val Dist 14.0626
# Epoch 37: Train Loss 38.1690, Val Dist 14.0358
# Epoch 38: Train Loss 38.1600, Val Dist 14.1129
# Epoch 39: Train Loss 38.1618, Val Dist 14.1377
# Epoch 40: Train Loss 38.0444, Val Dist 14.0481
# Epoch 41: Train Loss 38.0167, Val Dist 13.9706
#   -> Saved Best Model (Dist: 13.9706)
# Epoch 42: Train Loss 38.0410, Val Dist 14.0339
# Epoch 43: Train Loss 38.0097, Val Dist 14.0490
# Epoch 44: Train Loss 38.0228, Val Dist 14.0105
# Epoch 45: Train Loss 37.9581, Val Dist 14.0815
# Epoch 46: Train Loss 37.8862, Val Dist 13.9198
#   -> Saved Best Model (Dist: 13.9198)
# Epoch 47: Train Loss 37.9453, Val Dist 14.0129
# Epoch 48: Train Loss 37.9249, Val Dist 13.9773
# Epoch 49: Train Loss 37.8855, Val Dist 13.9433
# Epoch 50: Train Loss 37.8209, Val Dist 13.9594
# Epoch 51: Train Loss 37.9306, Val Dist 14.0180
# Epoch 52: Train Loss 37.8760, Val Dist 13.9858
# Epoch 53: Train Loss 37.8660, Val Dist 13.9824
# Epoch 54: Train Loss 37.8982, Val Dist 13.9621
# Epoch 55: Train Loss 37.9075, Val Dist 14.0136
# Epoch 56: Train Loss 37.8982, Val Dist 14.0247
# Epoch 57: Train Loss 37.8834, Val Dist 13.9591
# Epoch 58: Train Loss 37.7867, Val Dist 14.0044
# Epoch 59: Train Loss 37.8692, Val Dist 13.9626
# Epoch 60: Train Loss 37.8881, Val Dist 14.0211
# Epoch 61: Train Loss 37.7996, Val Dist 14.0164
# Early Stopping
# Fold 4 Finished. Best Valid Dist: 13.9198
# [Fold 5] Seed fixed to 46
#
# === Fold 5/10 ===
# Pre-rendering 14016 images (Cache Enabled)...
# Caching Images: 100%|██████████| 14016/14016 [00:00<00:00, 15942.73it/s]
# Pre-rendering 1412 images (Cache Enabled)...
# Caching Images: 100%|██████████| 1412/1412 [00:00<00:00, 13475.68it/s]
# Epoch 1: Train Loss 67.2305, Val Dist 20.5034
#   -> Saved Best Model (Dist: 20.5034)
# Epoch 2: Train Loss 50.0672, Val Dist 19.3054
#   -> Saved Best Model (Dist: 19.3054)
# Epoch 3: Train Loss 47.0281, Val Dist 17.6697
#   -> Saved Best Model (Dist: 17.6697)
# Epoch 4: Train Loss 45.4962, Val Dist 17.8080
# Epoch 5: Train Loss 44.5284, Val Dist 16.5534
#   -> Saved Best Model (Dist: 16.5534)
# Epoch 6: Train Loss 43.6325, Val Dist 16.4159
#   -> Saved Best Model (Dist: 16.4159)
# Epoch 7: Train Loss 43.0057, Val Dist 15.8362
#   -> Saved Best Model (Dist: 15.8362)
# Epoch 8: Train Loss 42.5739, Val Dist 16.0394
# Epoch 9: Train Loss 42.0585, Val Dist 15.6958
#   -> Saved Best Model (Dist: 15.6958)
# Epoch 10: Train Loss 41.6929, Val Dist 15.2994
#   -> Saved Best Model (Dist: 15.2994)
# Epoch 11: Train Loss 41.4578, Val Dist 15.2737
#   -> Saved Best Model (Dist: 15.2737)
# Epoch 12: Train Loss 41.2760, Val Dist 15.0735
#   -> Saved Best Model (Dist: 15.0735)
# Epoch 13: Train Loss 41.0184, Val Dist 15.0592
#   -> Saved Best Model (Dist: 15.0592)
# Epoch 14: Train Loss 40.6450, Val Dist 14.6221
#   -> Saved Best Model (Dist: 14.6221)
# Epoch 15: Train Loss 40.6564, Val Dist 14.4750
#   -> Saved Best Model (Dist: 14.4750)
# Epoch 16: Train Loss 40.3497, Val Dist 14.8158
# Epoch 17: Train Loss 40.1914, Val Dist 14.7796
# Epoch 18: Train Loss 40.0861, Val Dist 14.7167
# Epoch 19: Train Loss 39.8874, Val Dist 14.6289
# Epoch 20: Train Loss 39.3716, Val Dist 14.3745
#   -> Saved Best Model (Dist: 14.3745)
# Epoch 21: Train Loss 39.3331, Val Dist 14.3693
#   -> Saved Best Model (Dist: 14.3693)
# Epoch 22: Train Loss 39.2859, Val Dist 14.2861
#   -> Saved Best Model (Dist: 14.2861)
# Epoch 23: Train Loss 39.1287, Val Dist 14.4360
# Epoch 24: Train Loss 39.0861, Val Dist 14.1946
#   -> Saved Best Model (Dist: 14.1946)
# Epoch 25: Train Loss 38.9823, Val Dist 14.2785
# Epoch 26: Train Loss 39.0002, Val Dist 14.1494
#   -> Saved Best Model (Dist: 14.1494)
# Epoch 27: Train Loss 38.9516, Val Dist 14.1488
#   -> Saved Best Model (Dist: 14.1488)
# Epoch 28: Train Loss 38.7967, Val Dist 14.1558
# Epoch 29: Train Loss 38.8150, Val Dist 14.2792
# Epoch 30: Train Loss 38.7458, Val Dist 14.1368
#   -> Saved Best Model (Dist: 14.1368)
# Epoch 31: Train Loss 38.5756, Val Dist 14.0134
#   -> Saved Best Model (Dist: 14.0134)
# Epoch 32: Train Loss 38.5825, Val Dist 14.0646
# Epoch 33: Train Loss 38.5333, Val Dist 14.1448
# Epoch 34: Train Loss 38.4909, Val Dist 13.9656
#   -> Saved Best Model (Dist: 13.9656)
# Epoch 35: Train Loss 38.4354, Val Dist 14.1237
# Epoch 36: Train Loss 38.4163, Val Dist 14.0600
# Epoch 37: Train Loss 38.3015, Val Dist 14.0783
# Epoch 38: Train Loss 38.2995, Val Dist 13.9193
#   -> Saved Best Model (Dist: 13.9193)
# Epoch 39: Train Loss 38.2012, Val Dist 14.1272
# Epoch 40: Train Loss 38.2321, Val Dist 14.0428
# Epoch 41: Train Loss 38.1276, Val Dist 14.0943
# Epoch 42: Train Loss 38.0549, Val Dist 13.8198
#   -> Saved Best Model (Dist: 13.8198)
# Epoch 43: Train Loss 38.0315, Val Dist 14.1411
# Epoch 44: Train Loss 38.0459, Val Dist 13.8960
# Epoch 45: Train Loss 38.0004, Val Dist 13.8216
# Epoch 46: Train Loss 37.9338, Val Dist 14.2044
# Epoch 47: Train Loss 37.6607, Val Dist 13.8408
# Epoch 48: Train Loss 37.6260, Val Dist 13.8177
#   -> Saved Best Model (Dist: 13.8177)
# Epoch 49: Train Loss 37.5622, Val Dist 13.8559
# Epoch 50: Train Loss 37.5116, Val Dist 13.8800
# Epoch 51: Train Loss 37.5356, Val Dist 13.8905
# Epoch 52: Train Loss 37.4840, Val Dist 13.8726
# Epoch 53: Train Loss 37.3139, Val Dist 13.6947
#   -> Saved Best Model (Dist: 13.6947)
# Epoch 54: Train Loss 37.2719, Val Dist 13.7331
# Epoch 55: Train Loss 37.2079, Val Dist 13.8149
# Epoch 56: Train Loss 37.2564, Val Dist 13.7751
# Epoch 57: Train Loss 37.1983, Val Dist 13.8195
# Epoch 58: Train Loss 37.2100, Val Dist 13.7432
# Epoch 59: Train Loss 37.1578, Val Dist 13.7538
# Epoch 60: Train Loss 37.1059, Val Dist 13.7915
# Epoch 61: Train Loss 37.1127, Val Dist 13.7942
# Epoch 62: Train Loss 37.0536, Val Dist 13.7776
# Epoch 63: Train Loss 37.1052, Val Dist 13.7470
# Epoch 64: Train Loss 37.0534, Val Dist 13.7324
# Epoch 65: Train Loss 37.0562, Val Dist 13.7333
# Epoch 66: Train Loss 36.9620, Val Dist 13.7438
# Epoch 67: Train Loss 36.9743, Val Dist 13.7313
# Epoch 68: Train Loss 36.9909, Val Dist 13.7300
# Early Stopping
# Fold 5 Finished. Best Valid Dist: 13.6947
# [Fold 6] Seed fixed to 47
#
# === Fold 6/10 ===
# Pre-rendering 13844 images (Cache Enabled)...
# Caching Images: 100%|██████████| 13844/13844 [00:00<00:00, 17741.15it/s]
# Pre-rendering 1584 images (Cache Enabled)...
# Caching Images: 100%|██████████| 1584/1584 [00:00<00:00, 13536.05it/s]
# Epoch 1: Train Loss 66.5987, Val Dist 20.0233
#   -> Saved Best Model (Dist: 20.0233)
# Epoch 2: Train Loss 49.6501, Val Dist 19.5998
#   -> Saved Best Model (Dist: 19.5998)
# Epoch 3: Train Loss 46.8793, Val Dist 17.6129
#   -> Saved Best Model (Dist: 17.6129)
# Epoch 4: Train Loss 45.7794, Val Dist 17.2830
#   -> Saved Best Model (Dist: 17.2830)
# Epoch 5: Train Loss 44.6238, Val Dist 16.9324
#   -> Saved Best Model (Dist: 16.9324)
# Epoch 6: Train Loss 43.9194, Val Dist 16.0933
#   -> Saved Best Model (Dist: 16.0933)
# Epoch 7: Train Loss 43.2575, Val Dist 16.2038
# Epoch 8: Train Loss 42.7689, Val Dist 15.7866
#   -> Saved Best Model (Dist: 15.7866)
# Epoch 9: Train Loss 42.3383, Val Dist 15.4837
#   -> Saved Best Model (Dist: 15.4837)
# Epoch 10: Train Loss 41.9941, Val Dist 15.4885
# Epoch 11: Train Loss 41.7472, Val Dist 14.7195
#   -> Saved Best Model (Dist: 14.7195)
# Epoch 12: Train Loss 41.4485, Val Dist 15.9884
# Epoch 13: Train Loss 41.3583, Val Dist 15.9651
# Epoch 14: Train Loss 41.0207, Val Dist 15.1797
# Epoch 15: Train Loss 40.8531, Val Dist 14.6698
#   -> Saved Best Model (Dist: 14.6698)
# Epoch 16: Train Loss 40.6550, Val Dist 14.1818
#   -> Saved Best Model (Dist: 14.1818)
# Epoch 17: Train Loss 40.3896, Val Dist 14.5123
# Epoch 18: Train Loss 40.2460, Val Dist 14.3985
# Epoch 19: Train Loss 40.1262, Val Dist 14.1363
#   -> Saved Best Model (Dist: 14.1363)
# Epoch 20: Train Loss 40.0972, Val Dist 14.3515
# Epoch 21: Train Loss 39.8989, Val Dist 14.4632
# Epoch 22: Train Loss 39.7941, Val Dist 14.0484
#   -> Saved Best Model (Dist: 14.0484)
# Epoch 23: Train Loss 39.7374, Val Dist 14.1056
# Epoch 24: Train Loss 39.5228, Val Dist 13.8450
#   -> Saved Best Model (Dist: 13.8450)
# Epoch 25: Train Loss 39.4295, Val Dist 13.7330
#   -> Saved Best Model (Dist: 13.7330)
# Epoch 26: Train Loss 39.3633, Val Dist 13.8429
# Epoch 27: Train Loss 39.2548, Val Dist 13.9714
# Epoch 28: Train Loss 39.2288, Val Dist 13.9011
# Epoch 29: Train Loss 39.1248, Val Dist 13.6795
#   -> Saved Best Model (Dist: 13.6795)
# Epoch 30: Train Loss 39.0314, Val Dist 13.6227
#   -> Saved Best Model (Dist: 13.6227)
# Epoch 31: Train Loss 38.8597, Val Dist 14.1798
# Epoch 32: Train Loss 38.8379, Val Dist 13.6336
# Epoch 33: Train Loss 38.7656, Val Dist 13.6142
#   -> Saved Best Model (Dist: 13.6142)
# Epoch 34: Train Loss 38.7090, Val Dist 14.3573
# Epoch 35: Train Loss 38.6214, Val Dist 13.6862
# Epoch 36: Train Loss 38.5428, Val Dist 13.5684
#   -> Saved Best Model (Dist: 13.5684)
# Epoch 37: Train Loss 38.4618, Val Dist 13.5745
# Epoch 38: Train Loss 38.3071, Val Dist 13.7266
# Epoch 39: Train Loss 38.2761, Val Dist 13.7341
# Epoch 40: Train Loss 38.2282, Val Dist 13.7469
# Epoch 41: Train Loss 37.7651, Val Dist 13.4418
#   -> Saved Best Model (Dist: 13.4418)
# Epoch 42: Train Loss 37.6575, Val Dist 13.6242
# Epoch 43: Train Loss 37.5152, Val Dist 13.3549
#   -> Saved Best Model (Dist: 13.3549)
# Epoch 44: Train Loss 37.4979, Val Dist 13.5017
# Epoch 45: Train Loss 37.4900, Val Dist 13.3795
# Epoch 46: Train Loss 37.4389, Val Dist 13.4732
# Epoch 47: Train Loss 37.3975, Val Dist 13.3506
#   -> Saved Best Model (Dist: 13.3506)
# Epoch 48: Train Loss 37.3251, Val Dist 13.4584
# Epoch 49: Train Loss 37.3069, Val Dist 13.4278
# Epoch 50: Train Loss 37.1550, Val Dist 13.4111
# Epoch 51: Train Loss 37.1591, Val Dist 13.4465
# Epoch 52: Train Loss 36.9961, Val Dist 13.3434
#   -> Saved Best Model (Dist: 13.3434)
# Epoch 53: Train Loss 36.8209, Val Dist 13.3738
# Epoch 54: Train Loss 36.7566, Val Dist 13.3001
#   -> Saved Best Model (Dist: 13.3001)
# Epoch 55: Train Loss 36.7303, Val Dist 13.3726
# Epoch 56: Train Loss 36.7627, Val Dist 13.3463
# Epoch 57: Train Loss 36.7129, Val Dist 13.3590
# Epoch 58: Train Loss 36.6404, Val Dist 13.4042
# Epoch 59: Train Loss 36.5302, Val Dist 13.3810
# Epoch 60: Train Loss 36.5069, Val Dist 13.3370
# Epoch 61: Train Loss 36.4458, Val Dist 13.3900
# Epoch 62: Train Loss 36.4038, Val Dist 13.3706
# Epoch 63: Train Loss 36.3810, Val Dist 13.3482
# Epoch 64: Train Loss 36.4006, Val Dist 13.3390
# Epoch 65: Train Loss 36.3361, Val Dist 13.3523
# Epoch 66: Train Loss 36.3218, Val Dist 13.3714
# Epoch 67: Train Loss 36.2669, Val Dist 13.3272
# Epoch 68: Train Loss 36.2976, Val Dist 13.3704
# Epoch 69: Train Loss 36.2188, Val Dist 13.3691
# Early Stopping
# Fold 6 Finished. Best Valid Dist: 13.3001
# [Fold 7] Seed fixed to 48
#
# === Fold 7/10 ===
# Pre-rendering 13884 images (Cache Enabled)...
# Caching Images: 100%|██████████| 13884/13884 [00:00<00:00, 18565.70it/s]
# Pre-rendering 1544 images (Cache Enabled)...
# Caching Images: 100%|██████████| 1544/1544 [00:00<00:00, 18108.37it/s]
# Epoch 1: Train Loss 66.3914, Val Dist 18.8443
#   -> Saved Best Model (Dist: 18.8443)
# Epoch 2: Train Loss 49.0248, Val Dist 17.6773
#   -> Saved Best Model (Dist: 17.6773)
# Epoch 3: Train Loss 46.5508, Val Dist 16.0368
#   -> Saved Best Model (Dist: 16.0368)
# Epoch 4: Train Loss 45.4341, Val Dist 15.8621
#   -> Saved Best Model (Dist: 15.8621)
# Epoch 5: Train Loss 44.3023, Val Dist 16.1080
# Epoch 6: Train Loss 43.7170, Val Dist 15.2920
#   -> Saved Best Model (Dist: 15.2920)
# Epoch 7: Train Loss 42.9621, Val Dist 15.3524
# Epoch 8: Train Loss 42.7016, Val Dist 14.8243
#   -> Saved Best Model (Dist: 14.8243)
# Epoch 9: Train Loss 42.2784, Val Dist 14.3532
#   -> Saved Best Model (Dist: 14.3532)
# Epoch 10: Train Loss 41.8065, Val Dist 14.1743
#   -> Saved Best Model (Dist: 14.1743)
# Epoch 11: Train Loss 41.5850, Val Dist 14.8137
# Epoch 12: Train Loss 41.3686, Val Dist 14.7470
# Epoch 13: Train Loss 41.0757, Val Dist 14.1217
#   -> Saved Best Model (Dist: 14.1217)
# Epoch 14: Train Loss 40.9975, Val Dist 13.9777
#   -> Saved Best Model (Dist: 13.9777)
# Epoch 15: Train Loss 40.7118, Val Dist 13.9881
# Epoch 16: Train Loss 40.4801, Val Dist 14.2451
# Epoch 17: Train Loss 40.4740, Val Dist 13.9784
# Epoch 18: Train Loss 40.1527, Val Dist 14.0270
# Epoch 19: Train Loss 39.7444, Val Dist 13.4305
#   -> Saved Best Model (Dist: 13.4305)
# Epoch 20: Train Loss 39.6041, Val Dist 13.7249
# Epoch 21: Train Loss 39.4686, Val Dist 13.5246
# Epoch 22: Train Loss 39.4252, Val Dist 13.4992
# Epoch 23: Train Loss 39.3816, Val Dist 13.4926
# Epoch 24: Train Loss 39.1278, Val Dist 13.2818
#   -> Saved Best Model (Dist: 13.2818)
# Epoch 25: Train Loss 39.0450, Val Dist 13.2939
# Epoch 26: Train Loss 38.9841, Val Dist 13.3048
# Epoch 27: Train Loss 38.9821, Val Dist 13.1807
#   -> Saved Best Model (Dist: 13.1807)
# Epoch 28: Train Loss 38.9557, Val Dist 13.2549
# Epoch 29: Train Loss 38.8948, Val Dist 13.2333
# Epoch 30: Train Loss 38.8044, Val Dist 13.4168
# Epoch 31: Train Loss 38.7225, Val Dist 13.1911
# Epoch 32: Train Loss 38.6571, Val Dist 13.1516
#   -> Saved Best Model (Dist: 13.1516)
# Epoch 33: Train Loss 38.6122, Val Dist 13.1206
#   -> Saved Best Model (Dist: 13.1206)
# Epoch 34: Train Loss 38.5436, Val Dist 13.2488
# Epoch 35: Train Loss 38.5229, Val Dist 13.1443
# Epoch 36: Train Loss 38.5224, Val Dist 13.0941
#   -> Saved Best Model (Dist: 13.0941)
# Epoch 37: Train Loss 38.4693, Val Dist 13.1461
# Epoch 38: Train Loss 38.4902, Val Dist 13.1509
# Epoch 39: Train Loss 38.4485, Val Dist 13.1597
# Epoch 40: Train Loss 38.4485, Val Dist 13.1167
# Epoch 41: Train Loss 38.3455, Val Dist 13.0677
#   -> Saved Best Model (Dist: 13.0677)
# Epoch 42: Train Loss 38.2891, Val Dist 13.1029
# Epoch 43: Train Loss 38.3011, Val Dist 13.1148
# Epoch 44: Train Loss 38.2550, Val Dist 13.0956
# Epoch 45: Train Loss 38.3092, Val Dist 13.1614
# Epoch 46: Train Loss 38.2287, Val Dist 13.0623
#   -> Saved Best Model (Dist: 13.0623)
# Epoch 47: Train Loss 38.2202, Val Dist 13.0665
# Epoch 48: Train Loss 38.1985, Val Dist 13.0695
# Epoch 49: Train Loss 38.1869, Val Dist 13.0830
# Epoch 50: Train Loss 38.1354, Val Dist 13.0484
#   -> Saved Best Model (Dist: 13.0484)
# Epoch 51: Train Loss 38.1680, Val Dist 13.0674
# Epoch 52: Train Loss 38.1511, Val Dist 13.0433
#   -> Saved Best Model (Dist: 13.0433)
# Epoch 53: Train Loss 38.2216, Val Dist 13.0577
# Epoch 54: Train Loss 38.0941, Val Dist 13.0521
# Epoch 55: Train Loss 38.1647, Val Dist 13.0341
#   -> Saved Best Model (Dist: 13.0341)
# Epoch 56: Train Loss 38.1276, Val Dist 13.0316
#   -> Saved Best Model (Dist: 13.0316)
# Epoch 57: Train Loss 38.1874, Val Dist 13.0288
#   -> Saved Best Model (Dist: 13.0288)
# Epoch 58: Train Loss 38.1960, Val Dist 13.0416
# Epoch 59: Train Loss 38.1357, Val Dist 13.0311
# Epoch 60: Train Loss 38.1351, Val Dist 13.0585
# Epoch 61: Train Loss 38.0972, Val Dist 13.0574
# Epoch 62: Train Loss 38.1083, Val Dist 13.0427
# Epoch 63: Train Loss 38.0750, Val Dist 13.0377
# Epoch 64: Train Loss 38.0703, Val Dist 13.0530
# Epoch 65: Train Loss 38.0421, Val Dist 13.0384
# Epoch 66: Train Loss 38.0929, Val Dist 13.0487
# Epoch 67: Train Loss 38.1477, Val Dist 13.0389
# Epoch 68: Train Loss 38.0694, Val Dist 13.0449
# Epoch 69: Train Loss 38.1134, Val Dist 13.0642
# Epoch 70: Train Loss 38.0584, Val Dist 13.0623
# Epoch 71: Train Loss 38.0962, Val Dist 13.0450
# Epoch 72: Train Loss 38.0893, Val Dist 13.0502
# Early Stopping
# Fold 7 Finished. Best Valid Dist: 13.0288
# [Fold 8] Seed fixed to 49
#
# === Fold 8/10 ===
# Pre-rendering 13933 images (Cache Enabled)...
# Caching Images: 100%|██████████| 13933/13933 [00:00<00:00, 14683.23it/s]
# Pre-rendering 1495 images (Cache Enabled)...
# Caching Images: 100%|██████████| 1495/1495 [00:00<00:00, 12930.09it/s]
# Epoch 1: Train Loss 69.9923, Val Dist 18.5991
#   -> Saved Best Model (Dist: 18.5991)
# Epoch 2: Train Loss 50.3471, Val Dist 18.5446
#   -> Saved Best Model (Dist: 18.5446)
# Epoch 3: Train Loss 46.9700, Val Dist 16.3484
#   -> Saved Best Model (Dist: 16.3484)
# Epoch 4: Train Loss 45.4162, Val Dist 16.8267
# Epoch 5: Train Loss 44.5578, Val Dist 15.9149
#   -> Saved Best Model (Dist: 15.9149)
# Epoch 6: Train Loss 43.6742, Val Dist 15.7595
#   -> Saved Best Model (Dist: 15.7595)
# Epoch 7: Train Loss 42.9129, Val Dist 15.0397
#   -> Saved Best Model (Dist: 15.0397)
# Epoch 8: Train Loss 42.5489, Val Dist 15.2520
# Epoch 9: Train Loss 42.3365, Val Dist 15.1569
# Epoch 10: Train Loss 41.6178, Val Dist 14.3286
#   -> Saved Best Model (Dist: 14.3286)
# Epoch 11: Train Loss 41.5259, Val Dist 14.4006
# Epoch 12: Train Loss 41.2720, Val Dist 14.2705
#   -> Saved Best Model (Dist: 14.2705)
# Epoch 13: Train Loss 40.9052, Val Dist 14.3057
# Epoch 14: Train Loss 40.7070, Val Dist 14.5222
# Epoch 15: Train Loss 40.5245, Val Dist 14.2549
#   -> Saved Best Model (Dist: 14.2549)
# Epoch 16: Train Loss 40.3677, Val Dist 14.3631
# Epoch 17: Train Loss 40.1375, Val Dist 14.2390
#   -> Saved Best Model (Dist: 14.2390)
# Epoch 18: Train Loss 40.0136, Val Dist 13.6681
#   -> Saved Best Model (Dist: 13.6681)
# Epoch 19: Train Loss 39.7897, Val Dist 14.1581
# Epoch 20: Train Loss 39.6442, Val Dist 13.7217
# Epoch 21: Train Loss 39.5056, Val Dist 13.8703
# Epoch 22: Train Loss 39.4723, Val Dist 13.6019
#   -> Saved Best Model (Dist: 13.6019)
# Epoch 23: Train Loss 39.3445, Val Dist 13.6691
# Epoch 24: Train Loss 39.2100, Val Dist 13.6770
# Epoch 25: Train Loss 39.1415, Val Dist 13.8690
# Epoch 26: Train Loss 39.0661, Val Dist 14.1387
# Epoch 27: Train Loss 38.6502, Val Dist 13.5194
#   -> Saved Best Model (Dist: 13.5194)
# Epoch 28: Train Loss 38.4895, Val Dist 13.4201
#   -> Saved Best Model (Dist: 13.4201)
# Epoch 29: Train Loss 38.3705, Val Dist 13.4331
# Epoch 30: Train Loss 38.2921, Val Dist 13.2906
#   -> Saved Best Model (Dist: 13.2906)
# Epoch 31: Train Loss 38.3204, Val Dist 13.3918
# Epoch 32: Train Loss 38.2019, Val Dist 13.4074
# Epoch 33: Train Loss 38.2662, Val Dist 13.4546
# Epoch 34: Train Loss 38.1525, Val Dist 13.2116
#   -> Saved Best Model (Dist: 13.2116)
# Epoch 35: Train Loss 38.1161, Val Dist 13.5003
# Epoch 36: Train Loss 37.9922, Val Dist 13.3298
# Epoch 37: Train Loss 38.0062, Val Dist 13.4219
# Epoch 38: Train Loss 37.9700, Val Dist 13.3426
# Epoch 39: Train Loss 37.6888, Val Dist 13.1734
#   -> Saved Best Model (Dist: 13.1734)
# Epoch 40: Train Loss 37.5758, Val Dist 13.1755
# Epoch 41: Train Loss 37.6050, Val Dist 13.1834
# Epoch 42: Train Loss 37.5889, Val Dist 13.2132
# Epoch 43: Train Loss 37.5369, Val Dist 13.2758
# Epoch 44: Train Loss 37.4206, Val Dist 13.0936
#   -> Saved Best Model (Dist: 13.0936)
# Epoch 45: Train Loss 37.3207, Val Dist 13.1144
# Epoch 46: Train Loss 37.3174, Val Dist 13.1772
# Epoch 47: Train Loss 37.2638, Val Dist 13.0972
# Epoch 48: Train Loss 37.2820, Val Dist 13.0797
#   -> Saved Best Model (Dist: 13.0797)
# Epoch 49: Train Loss 37.2294, Val Dist 13.0615
#   -> Saved Best Model (Dist: 13.0615)
# Epoch 50: Train Loss 37.1977, Val Dist 13.0844
# Epoch 51: Train Loss 37.1859, Val Dist 13.0577
#   -> Saved Best Model (Dist: 13.0577)
# Epoch 52: Train Loss 37.2406, Val Dist 13.1748
# Epoch 53: Train Loss 37.1954, Val Dist 13.0705
# Epoch 54: Train Loss 37.1834, Val Dist 13.0991
# Epoch 55: Train Loss 37.1533, Val Dist 13.1237
# Epoch 56: Train Loss 37.0157, Val Dist 13.1311
# Epoch 57: Train Loss 37.0259, Val Dist 13.0824
# Epoch 58: Train Loss 37.0688, Val Dist 13.0973
# Epoch 59: Train Loss 37.0253, Val Dist 13.0866
# Epoch 60: Train Loss 36.9919, Val Dist 13.0644
# Epoch 61: Train Loss 37.0071, Val Dist 13.0440
#   -> Saved Best Model (Dist: 13.0440)
# Epoch 62: Train Loss 36.9830, Val Dist 13.0653
# Epoch 63: Train Loss 36.9910, Val Dist 13.0642
# Epoch 64: Train Loss 36.9516, Val Dist 13.0520
# Epoch 65: Train Loss 36.8892, Val Dist 13.0652
# Epoch 66: Train Loss 36.8828, Val Dist 13.0680
# Epoch 67: Train Loss 36.9282, Val Dist 13.0514
# Epoch 68: Train Loss 36.9038, Val Dist 13.0631
# Epoch 69: Train Loss 36.9221, Val Dist 13.0467
# Epoch 70: Train Loss 36.8750, Val Dist 13.0597
# Epoch 71: Train Loss 36.9008, Val Dist 13.0750
# Epoch 72: Train Loss 36.9589, Val Dist 13.0261
#   -> Saved Best Model (Dist: 13.0261)
# Epoch 73: Train Loss 36.9242, Val Dist 13.0526
# Epoch 74: Train Loss 36.9265, Val Dist 13.0457
# Epoch 75: Train Loss 36.8851, Val Dist 13.0790
# Epoch 76: Train Loss 36.9202, Val Dist 13.0720
# Epoch 77: Train Loss 36.9130, Val Dist 13.0471
# Epoch 78: Train Loss 36.9454, Val Dist 13.0424
# Epoch 79: Train Loss 36.8623, Val Dist 13.0444
# Epoch 80: Train Loss 36.8531, Val Dist 13.0619
# Epoch 81: Train Loss 36.8519, Val Dist 13.0621
# Epoch 82: Train Loss 36.9175, Val Dist 13.0834
# Epoch 83: Train Loss 36.8633, Val Dist 13.0513
# Epoch 84: Train Loss 36.8742, Val Dist 13.0504
# Epoch 85: Train Loss 36.8799, Val Dist 13.0927
# Epoch 86: Train Loss 36.8826, Val Dist 13.0554
# Epoch 87: Train Loss 36.9201, Val Dist 13.0561
# Early Stopping
# Fold 8 Finished. Best Valid Dist: 13.0261
# [Fold 9] Seed fixed to 50
#
# === Fold 9/10 ===
# Pre-rendering 13806 images (Cache Enabled)...
# Caching Images: 100%|██████████| 13806/13806 [00:00<00:00, 15043.78it/s]
# Pre-rendering 1622 images (Cache Enabled)...
# Caching Images: 100%|██████████| 1622/1622 [00:00<00:00, 12388.62it/s]
# Epoch 1: Train Loss 66.4907, Val Dist 19.1200
#   -> Saved Best Model (Dist: 19.1200)
# Epoch 2: Train Loss 48.8982, Val Dist 17.5108
#   -> Saved Best Model (Dist: 17.5108)
# Epoch 3: Train Loss 46.4889, Val Dist 16.7086
#   -> Saved Best Model (Dist: 16.7086)
# Epoch 4: Train Loss 45.2339, Val Dist 16.6576
#   -> Saved Best Model (Dist: 16.6576)
# Epoch 5: Train Loss 43.9652, Val Dist 17.0164
# Epoch 6: Train Loss 43.3344, Val Dist 16.6429
#   -> Saved Best Model (Dist: 16.6429)
# Epoch 7: Train Loss 42.6804, Val Dist 15.6511
#   -> Saved Best Model (Dist: 15.6511)
# Epoch 8: Train Loss 42.2027, Val Dist 15.4655
#   -> Saved Best Model (Dist: 15.4655)
# Epoch 9: Train Loss 41.8255, Val Dist 15.3531
#   -> Saved Best Model (Dist: 15.3531)
# Epoch 10: Train Loss 41.5819, Val Dist 15.6520
# Epoch 11: Train Loss 41.2772, Val Dist 15.0439
#   -> Saved Best Model (Dist: 15.0439)
# Epoch 12: Train Loss 41.0907, Val Dist 14.8488
#   -> Saved Best Model (Dist: 14.8488)
# Epoch 13: Train Loss 40.6915, Val Dist 14.9241
# Epoch 14: Train Loss 40.6531, Val Dist 14.9056
# Epoch 15: Train Loss 40.3498, Val Dist 14.5385
#   -> Saved Best Model (Dist: 14.5385)
# Epoch 16: Train Loss 40.2389, Val Dist 14.8604
# Epoch 17: Train Loss 40.0786, Val Dist 14.7617
# Epoch 18: Train Loss 40.0373, Val Dist 14.9607
# Epoch 19: Train Loss 39.8467, Val Dist 14.4924
#   -> Saved Best Model (Dist: 14.4924)
# Epoch 20: Train Loss 39.6300, Val Dist 14.4609
#   -> Saved Best Model (Dist: 14.4609)
# Epoch 21: Train Loss 39.5060, Val Dist 14.8522
# Epoch 22: Train Loss 39.4678, Val Dist 14.5185
# Epoch 23: Train Loss 39.3206, Val Dist 14.3983
#   -> Saved Best Model (Dist: 14.3983)
# Epoch 24: Train Loss 39.2558, Val Dist 14.5704
# Epoch 25: Train Loss 39.0817, Val Dist 14.5733
# Epoch 26: Train Loss 39.0077, Val Dist 14.5356
# Epoch 27: Train Loss 38.8826, Val Dist 14.4534
# Epoch 28: Train Loss 38.5039, Val Dist 14.4266
# Epoch 29: Train Loss 38.3140, Val Dist 14.3079
#   -> Saved Best Model (Dist: 14.3079)
# Epoch 30: Train Loss 38.2847, Val Dist 14.3403
# Epoch 31: Train Loss 38.2549, Val Dist 14.3201
# Epoch 32: Train Loss 38.1868, Val Dist 14.4251
# Epoch 33: Train Loss 38.1719, Val Dist 14.2277
#   -> Saved Best Model (Dist: 14.2277)
# Epoch 34: Train Loss 38.0905, Val Dist 14.2882
# Epoch 35: Train Loss 38.0581, Val Dist 14.5785
# Epoch 36: Train Loss 37.9900, Val Dist 14.2323
# Epoch 37: Train Loss 37.9572, Val Dist 14.2945
# Epoch 38: Train Loss 37.5923, Val Dist 14.1927
#   -> Saved Best Model (Dist: 14.1927)
# Epoch 39: Train Loss 37.6219, Val Dist 14.1004
#   -> Saved Best Model (Dist: 14.1004)
# Epoch 40: Train Loss 37.5730, Val Dist 14.1516
# Epoch 41: Train Loss 37.4755, Val Dist 14.0304
#   -> Saved Best Model (Dist: 14.0304)
# Epoch 42: Train Loss 37.5597, Val Dist 14.1788
# Epoch 43: Train Loss 37.5071, Val Dist 14.0763
# Epoch 44: Train Loss 37.5098, Val Dist 14.1659
# Epoch 45: Train Loss 37.3990, Val Dist 14.1449
# Epoch 46: Train Loss 37.2716, Val Dist 14.0649
# Epoch 47: Train Loss 37.2633, Val Dist 14.1579
# Epoch 48: Train Loss 37.2279, Val Dist 14.1599
# Epoch 49: Train Loss 37.2036, Val Dist 14.0842
# Epoch 50: Train Loss 37.0893, Val Dist 14.1087
# Epoch 51: Train Loss 37.1421, Val Dist 14.1723
# Epoch 52: Train Loss 37.0830, Val Dist 14.1083
# Epoch 53: Train Loss 37.0528, Val Dist 14.0744
# Epoch 54: Train Loss 37.0382, Val Dist 14.1063
# Epoch 55: Train Loss 36.9696, Val Dist 14.0778
# Epoch 56: Train Loss 37.0239, Val Dist 14.0585
# Early Stopping
# Fold 9 Finished. Best Valid Dist: 14.0304
# [Fold 10] Seed fixed to 51
#
# === Fold 10/10 ===
# Pre-rendering 13850 images (Cache Enabled)...
# Caching Images: 100%|██████████| 13850/13850 [00:00<00:00, 18098.67it/s]
# Pre-rendering 1578 images (Cache Enabled)...
# Caching Images: 100%|██████████| 1578/1578 [00:00<00:00, 13894.05it/s]
# Epoch 1: Train Loss 65.0167, Val Dist 20.4104
#   -> Saved Best Model (Dist: 20.4104)
# Epoch 2: Train Loss 49.1940, Val Dist 17.1019
#   -> Saved Best Model (Dist: 17.1019)
# Epoch 3: Train Loss 46.3951, Val Dist 16.4648
#   -> Saved Best Model (Dist: 16.4648)
# Epoch 4: Train Loss 45.3034, Val Dist 16.2010
#   -> Saved Best Model (Dist: 16.2010)
# Epoch 5: Train Loss 44.0738, Val Dist 15.2943
#   -> Saved Best Model (Dist: 15.2943)
# Epoch 6: Train Loss 43.3367, Val Dist 15.1729
#   -> Saved Best Model (Dist: 15.1729)
# Epoch 7: Train Loss 42.7738, Val Dist 16.0317
# Epoch 8: Train Loss 42.2959, Val Dist 15.4504
# Epoch 9: Train Loss 41.8664, Val Dist 14.9797
#   -> Saved Best Model (Dist: 14.9797)
# Epoch 10: Train Loss 41.5021, Val Dist 14.6082
#   -> Saved Best Model (Dist: 14.6082)
# Epoch 11: Train Loss 41.3164, Val Dist 14.8121
# Epoch 12: Train Loss 41.1851, Val Dist 14.2519
#   -> Saved Best Model (Dist: 14.2519)
# Epoch 13: Train Loss 40.7288, Val Dist 14.2885
# Epoch 14: Train Loss 40.5985, Val Dist 14.4477
# Epoch 15: Train Loss 40.5285, Val Dist 14.1326
#   -> Saved Best Model (Dist: 14.1326)
# Epoch 16: Train Loss 40.2211, Val Dist 14.4800
# Epoch 17: Train Loss 40.0595, Val Dist 14.4238
# Epoch 18: Train Loss 39.9852, Val Dist 14.1946
# Epoch 19: Train Loss 39.7890, Val Dist 14.3012
# Epoch 20: Train Loss 39.2967, Val Dist 13.9318
#   -> Saved Best Model (Dist: 13.9318)
# Epoch 21: Train Loss 39.1435, Val Dist 13.7392
#   -> Saved Best Model (Dist: 13.7392)
# Epoch 22: Train Loss 39.0955, Val Dist 13.6233
#   -> Saved Best Model (Dist: 13.6233)
# Epoch 23: Train Loss 39.0298, Val Dist 13.7423
# Epoch 24: Train Loss 38.9898, Val Dist 13.9439
# Epoch 25: Train Loss 38.9345, Val Dist 13.6728
# Epoch 26: Train Loss 38.8314, Val Dist 13.7294
# Epoch 27: Train Loss 38.5822, Val Dist 13.5461
#   -> Saved Best Model (Dist: 13.5461)
# Epoch 28: Train Loss 38.5543, Val Dist 13.5134
#   -> Saved Best Model (Dist: 13.5134)
# Epoch 29: Train Loss 38.4342, Val Dist 13.6239
# Epoch 30: Train Loss 38.4401, Val Dist 13.6250
# Epoch 31: Train Loss 38.4321, Val Dist 13.5858
# Epoch 32: Train Loss 38.3835, Val Dist 13.5956
# Epoch 33: Train Loss 38.2056, Val Dist 13.5442
# Epoch 34: Train Loss 38.1672, Val Dist 13.5164
# Epoch 35: Train Loss 38.1431, Val Dist 13.5305
# Epoch 36: Train Loss 38.0882, Val Dist 13.4901
#   -> Saved Best Model (Dist: 13.4901)
# Epoch 37: Train Loss 38.0814, Val Dist 13.4460
#   -> Saved Best Model (Dist: 13.4460)
# Epoch 38: Train Loss 38.0622, Val Dist 13.4688
# Epoch 39: Train Loss 38.0757, Val Dist 13.4814
# Epoch 40: Train Loss 38.0346, Val Dist 13.4761
# Epoch 41: Train Loss 38.0699, Val Dist 13.5176
# Epoch 42: Train Loss 37.9662, Val Dist 13.4012
#   -> Saved Best Model (Dist: 13.4012)
# Epoch 43: Train Loss 37.9548, Val Dist 13.3544
#   -> Saved Best Model (Dist: 13.3544)
# Epoch 44: Train Loss 37.9162, Val Dist 13.4331
# Epoch 45: Train Loss 37.9096, Val Dist 13.4305
# Epoch 46: Train Loss 37.8675, Val Dist 13.4138
# Epoch 47: Train Loss 37.9293, Val Dist 13.4615
# Epoch 48: Train Loss 37.8341, Val Dist 13.3526
#   -> Saved Best Model (Dist: 13.3526)
# Epoch 49: Train Loss 37.8393, Val Dist 13.3868
# Epoch 50: Train Loss 37.8269, Val Dist 13.3762
# Epoch 51: Train Loss 37.8289, Val Dist 13.3804
# Epoch 52: Train Loss 37.7914, Val Dist 13.4049
# Epoch 53: Train Loss 37.8511, Val Dist 13.3679
# Epoch 54: Train Loss 37.8070, Val Dist 13.3993
# Epoch 55: Train Loss 37.8314, Val Dist 13.3945
# Epoch 56: Train Loss 37.8445, Val Dist 13.3850
# Epoch 57: Train Loss 37.7635, Val Dist 13.3583
# Epoch 58: Train Loss 37.7949, Val Dist 13.3430
#   -> Saved Best Model (Dist: 13.3430)
# Epoch 59: Train Loss 37.7640, Val Dist 13.3681
# Epoch 60: Train Loss 37.8542, Val Dist 13.3704
# Epoch 61: Train Loss 37.7957, Val Dist 13.3532
# Epoch 62: Train Loss 37.7739, Val Dist 13.3945
# Epoch 63: Train Loss 37.7922, Val Dist 13.3588
# Epoch 64: Train Loss 37.7591, Val Dist 13.3487
# Epoch 65: Train Loss 37.7523, Val Dist 13.3909
# Epoch 66: Train Loss 37.7841, Val Dist 13.3982
# Epoch 67: Train Loss 37.7541, Val Dist 13.3732
# Epoch 68: Train Loss 37.7373, Val Dist 13.4251
# Epoch 69: Train Loss 37.7374, Val Dist 13.3769
# Epoch 70: Train Loss 37.8041, Val Dist 13.3585
# Epoch 71: Train Loss 37.7310, Val Dist 13.3569
# Epoch 72: Train Loss 37.7831, Val Dist 13.3709
# Epoch 73: Train Loss 37.8145, Val Dist 13.3548
# Early Stopping
# Fold 10 Finished. Best Valid Dist: 13.3430
# Average Score: 13.4654

# %%
# Inference V2.4
class TestMMDataset(Dataset):
    def __init__(self, sub_df, preprocessor, img_size=(68, 105)):
        self.sub_df = sub_df
        self.prep = preprocessor
        self.H, self.W = img_size
    def __len__(self): return len(self.sub_df)
    def _gen_img(self, cont):
        img = np.zeros((2, self.H, self.W), dtype=np.float32)
        if len(cont) == 0: return torch.tensor(img, dtype=torch.float32)
        xs, ys = cont[:,0], cont[:,1]
        xi = (xs*(self.W-1)).round().astype(int).clip(0, self.W-1)
        yi = (ys*(self.H-1)).round().astype(int).clip(0, self.H-1)
        for t in range(len(cont)):
            img[0, yi[t], xi[t]] = 1.0
            decay = (t+1)/len(cont)
            if t > 0:
                cv2.line(img[1], (xi[t-1], yi[t-1]), (xi[t], yi[t]), color=decay, thickness=1)
            else:
                img[1, yi[t], xi[t]] = decay
        return torch.tensor(img, dtype=torch.float32)
    def __getitem__(self, idx):
        path = self.sub_df.iloc[idx]['path']
        full_path = os.path.join("data", path[2:] if path.startswith("./") else path)
        try:
            df = pd.read_csv(full_path)
            eps = self.prep.transform(df, False)
        except: eps = []
        if not eps:
            d = self.prep.get_input_dim()
            c = torch.zeros((1,d), dtype=torch.float32)
            cat = torch.zeros((1,5), dtype=torch.long)
            img = torch.zeros((2, self.H, self.W), dtype=torch.float32)
        else:
            data = eps[0]
            c = torch.tensor(data['cont'], dtype=torch.float32)
            cat = torch.tensor(data['cat'], dtype=torch.long)
            img = self._gen_img(data['cont'])
        return img, c, cat

def test_collate(b):
    img, c, cat = zip(*b)
    ib = torch.stack(img)
    l = torch.tensor([len(x) for x in c], dtype=torch.long)
    cp = pad_sequence(c, batch_first=True)
    catp = pad_sequence(cat, batch_first=True)
    return ib, cp, catp, l

sub = pd.read_csv("data/sample_submission.csv")
tm = pd.read_csv("data/test.csv")
sub = sub.merge(tm, on="game_episode", how="left")

# Load Ref for dimensions
prep_ref = joblib.load('models_final_v2_4/preprocessor_v2_4_1.pkl')
GD = prep_ref.get_input_dim()
nT, nR = prep_ref.get_num_classes()

all_preds = []
for f in range(1, 11):
    try:
        prep = joblib.load(f'models_final_v2_4/preprocessor_v2_4_{f}.pkl')
        ds = TestMMDataset(sub, prep)
        dl = DataLoader(ds, 128, False, collate_fn=test_collate)
        model = MultiModalNetV8(GD, nT, nR).to(DEVICE)
        model.load_state_dict(torch.load(f'models_final_v2_4/multimodal_v2_4_{f}.pth', map_location=DEVICE))
        model.eval()
        fold_p = []
        with torch.no_grad():
            for b in tqdm(dl, desc=f'Fold {f}'):
                i, c, ct, l = [x.to(DEVICE) for x in b]
                p, _ = model(i, c, ct, l)
                pn = p.cpu().numpy()
                pn[:,0] *= 105; pn[:,1] *= 68
                fold_p.append(pn)
        all_preds.append(np.vstack(fold_p))
    except Exception as e: print(e)

if all_preds:
    avg = np.mean(all_preds, axis=0)
    sub['end_x'] = avg[:,0].clip(0, 105)
    sub['end_y'] = avg[:,1].clip(0, 68)
    sub[['game_episode','end_x','end_y']].to_csv('Final_env_v2_4.csv', index=False)
    print("Done: Final_env_v2_4.csv")
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_17032\1272777022.py:65: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'models_final_v2_4/multimodal_v2_4_{f}.pth', map_location=DEVICE))
# Fold 1: 100%|██████████| 19/19 [00:50<00:00,  2.68s/it]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_17032\1272777022.py:65: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'models_final_v2_4/multimodal_v2_4_{f}.pth', map_location=DEVICE))
# Fold 2: 100%|██████████| 19/19 [00:45<00:00,  2.42s/it]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_17032\1272777022.py:65: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'models_final_v2_4/multimodal_v2_4_{f}.pth', map_location=DEVICE))
# Fold 3: 100%|██████████| 19/19 [00:45<00:00,  2.39s/it]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_17032\1272777022.py:65: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'models_final_v2_4/multimodal_v2_4_{f}.pth', map_location=DEVICE))
# Fold 4: 100%|██████████| 19/19 [00:45<00:00,  2.41s/it]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_17032\1272777022.py:65: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'models_final_v2_4/multimodal_v2_4_{f}.pth', map_location=DEVICE))
# Fold 5: 100%|██████████| 19/19 [00:45<00:00,  2.41s/it]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_17032\1272777022.py:65: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'models_final_v2_4/multimodal_v2_4_{f}.pth', map_location=DEVICE))
# Fold 6: 100%|██████████| 19/19 [00:45<00:00,  2.39s/it]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_17032\1272777022.py:65: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'models_final_v2_4/multimodal_v2_4_{f}.pth', map_location=DEVICE))
# Fold 7: 100%|██████████| 19/19 [00:45<00:00,  2.38s/it]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_17032\1272777022.py:65: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'models_final_v2_4/multimodal_v2_4_{f}.pth', map_location=DEVICE))
# Fold 8: 100%|██████████| 19/19 [00:45<00:00,  2.39s/it]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_17032\1272777022.py:65: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'models_final_v2_4/multimodal_v2_4_{f}.pth', map_location=DEVICE))
# Fold 9: 100%|██████████| 19/19 [00:45<00:00,  2.40s/it]
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_17032\1272777022.py:65: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   model.load_state_dict(torch.load(f'models_final_v2_4/multimodal_v2_4_{f}.pth', map_location=DEVICE))
# Fold 10: 100%|██████████| 19/19 [00:45<00:00,  2.40s/it]
# Done: Final_env_v2_4.csv

# %%
# === R² (결정 계수) 평가 ===
from sklearn.metrics import r2_score

def evaluate_r2(train_df, n_splits=10):
    """학습된 모델로 각 Fold의 Validation에서 R² 계산"""
    gkf = GroupKFold(n_splits=n_splits)
    groups = train_df['game_id']
    
    # [FIX] Fold 1 기준 차원 고정 (학습 시와 동일)
    prep_ref = joblib.load("models_final_v2_4/preprocessor_v2_4_1.pkl")
    GD = prep_ref.get_input_dim()
    nT, nR = prep_ref.get_num_classes()
    
    all_preds, all_targets = [], []
    
    for fold, (train_idx, val_idx) in enumerate(gkf.split(train_df, groups=groups)):
        fold_seed = FOLD_SEEDS[(fold % 10) + 1]
        seed_everything(fold_seed)
        
        val_sub_df = train_df.iloc[val_idx].copy()
        
        preprocessor = joblib.load(f"models_final_v2_4/preprocessor_v2_4_{fold+1}.pkl")
        val_episodes = preprocessor.transform(val_sub_df, is_train=True)
        val_dataset = MultiModalDataset(val_episodes, augment=False, cache_images=True)
        val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False, collate_fn=multimodal_collate_fn)
        
        # [FIX] 모든 Fold에서 동일한 차원(nT=27, nR=21)으로 모델 생성
        model = MultiModalNetV8(GD, nT, nR).to(DEVICE)
        model.load_state_dict(torch.load(f"models_final_v2_4/multimodal_v2_4_{fold+1}.pth", map_location=DEVICE, weights_only=True))
        model.eval()
        
        with torch.no_grad():
            for batch in val_loader:
                imgs, cont, cat, lengths, target, aux_target = batch
                imgs, cont, cat, lengths, target = imgs.to(DEVICE), cont.to(DEVICE), cat.to(DEVICE), lengths.to(DEVICE), target.to(DEVICE)
                pred, _ = model(imgs, cont, cat, lengths)
                
                pred_real = pred.cpu().numpy() * np.array([105.0, 68.0])
                target_real = target.cpu().numpy() * np.array([105.0, 68.0])
                all_preds.append(pred_real)
                all_targets.append(target_real)
        
        print(f"Fold {fold+1} loaded.")
    
    all_preds = np.vstack(all_preds)
    all_targets = np.vstack(all_targets)
    
    r2_x = r2_score(all_targets[:, 0], all_preds[:, 0])
    r2_y = r2_score(all_targets[:, 1], all_preds[:, 1])
    r2_overall = r2_score(all_targets, all_preds)
    
    print(f"\n{'='*40}")
    print(f"R² Score (X):       {r2_x:.4f}")
    print(f"R² Score (Y):       {r2_y:.4f}")
    print(f"R² Score (Overall): {r2_overall:.4f}")
    print(f"{'='*40}")
    
    return r2_x, r2_y, r2_overall

r2_x, r2_y, r2_overall = evaluate_r2(train_df)
# Out:
# Pre-rendering 1601 images (Cache Enabled)...
# Caching Images: 100%|██████████| 1601/1601 [00:00<00:00, 17632.24it/s]
# Fold 1 loaded.
# Pre-rendering 1489 images (Cache Enabled)...
# Caching Images: 100%|██████████| 1489/1489 [00:00<00:00, 15625.56it/s]
# Fold 2 loaded.
# Pre-rendering 1550 images (Cache Enabled)...
# Caching Images: 100%|██████████| 1550/1550 [00:00<00:00, 16295.79it/s]
# Fold 3 loaded.
# Pre-rendering 1553 images (Cache Enabled)...
# Caching Images: 100%|██████████| 1553/1553 [00:00<00:00, 16193.34it/s]
# Fold 4 loaded.
# Pre-rendering 1412 images (Cache Enabled)...
# Caching Images: 100%|██████████| 1412/1412 [00:00<00:00, 16263.60it/s]
# Fold 5 loaded.
# Pre-rendering 1584 images (Cache Enabled)...
# Caching Images: 100%|██████████| 1584/1584 [00:00<00:00, 16729.39it/s]
# Fold 6 loaded.
# Pre-rendering 1544 images (Cache Enabled)...
# Caching Images: 100%|██████████| 1544/1544 [00:00<00:00, 16826.74it/s]
# Fold 7 loaded.
# Pre-rendering 1495 images (Cache Enabled)...
# Caching Images: 100%|██████████| 1495/1495 [00:00<00:00, 16814.24it/s]
# Fold 8 loaded.
# Pre-rendering 1622 images (Cache Enabled)...
# Caching Images: 100%|██████████| 1622/1622 [00:00<00:00, 18065.31it/s]
# Fold 9 loaded.
# Pre-rendering 1578 images (Cache Enabled)...
# Caching Images: 100%|██████████| 1578/1578 [00:00<00:00, 16696.17it/s]
# Fold 10 loaded.
#
# ========================================
# R² Score (X):       0.7546
# R² Score (Y):       0.7126
# R² Score (Overall): 0.7336
# ========================================

# %% [markdown]
# # 🔬 Ablation Study: 보조손실 / Cross-Attention 기여도
#
# 면접 대비용. **앞 셀(import, 데이터 로드, 모델 정의)을 먼저 실행한 뒤** 실행하세요.
# 시간 절약을 위해 **1-fold + 짧은 epoch**로 빠르게 비교합니다 (절대 성능이 아니라 *상대 비교*가 목적).
#
# 비교군:
# 1. **Full** — Cross-Attention + 보조손실 (현재 채택)
# 2. **No-Aux** — 보조손실 제거 (aux weight = 0)
# 3. **No-CrossAttn** — Cross-Attention 대신 단순 결합(seq_feat만 사용)

# %%
# === Ablation: Aux Loss / Cross-Attention ===
# 기존 정의 재사용: MultiModalNetV8, EuclideanLoss, MaskedSeqEuclideanLoss,
#   FootballPreprocessorMultimodal, MultiModalDataset, multimodal_collate_fn, seed_everything
import copy, numpy as np, torch, torch.nn as nn, torch.optim as optim
from sklearn.model_selection import GroupKFold
from torch.utils.data import DataLoader

# --- No-CrossAttn 변형: cross-attention을 건너뛰고 seq_feat을 그대로 사용 ---
class MultiModalNet_NoCross(MultiModalNetV8):
    def forward(self, img, cont, cat, lengths):
        cnn_map = self.cnn(img)
        emb_type = self.type_emb(cat[:, :, 0]); emb_result = self.result_emb(cat[:, :, 1])
        x_seq = torch.cat([cont, emb_type, emb_result], dim=2)
        from torch.nn.utils.rnn import pack_padded_sequence, pad_packed_sequence
        packed_fwd = pack_padded_sequence(x_seq, lengths.cpu(), batch_first=True, enforce_sorted=False)
        out_fwd_packed, _ = self.gru_fwd(packed_fwd)
        out_fwd, _ = pad_packed_sequence(out_fwd_packed, batch_first=True)
        x_seq_bwd = x_seq.clone()
        for i, length in enumerate(lengths):
            x_seq_bwd[i, :length] = x_seq[i, :length].flip(0)
        packed_bwd = pack_padded_sequence(x_seq_bwd, lengths.cpu(), batch_first=True, enforce_sorted=False)
        out_bwd_packed, _ = self.gru_bwd(packed_bwd)
        out_bwd, _ = pad_packed_sequence(out_bwd_packed, batch_first=True)
        for i, length in enumerate(lengths):
            out_bwd[i, :length] = out_bwd[i, :length].flip(0)
        gru_out_combined = torch.cat([out_fwd, out_bwd], dim=2)
        gru_ctx = self.gru_attn(gru_out_combined)
        seq_feat = torch.relu(self.gru_fc(gru_ctx))
        # Cross-Attention 생략: context 없이 seq_feat 자기 자신을 융합 입력으로
        fused = self.gated_fusion(seq_feat, seq_feat)
        final_out = self.final_fc(fused)
        aux_out = self.aux_fc(out_fwd)
        return final_out, aux_out

def train_one_fold(model_cls, aux_weight=0.5, epochs=20, batch_size=64, lr=1e-3, seed=42):
    seed_everything(seed)
    gkf = GroupKFold(n_splits=10)
    tr_idx, va_idx = next(gkf.split(train_df, groups=train_df['game_id']))
    tr_df, va_df = train_df.iloc[tr_idx].copy(), train_df.iloc[va_idx].copy()
    pre = FootballPreprocessorMultimodal(); pre.fit(tr_df)
    in_dim = pre.get_input_dim(); n_types, n_results = pre.get_num_classes()
    tr_ep = pre.transform(tr_df, is_train=True); va_ep = pre.transform(va_df, is_train=True)
    tr_ds = MultiModalDataset(tr_ep, augment=True, cache_images=True)
    va_ds = MultiModalDataset(va_ep, augment=False, cache_images=True)
    tr_ld = DataLoader(tr_ds, batch_size=batch_size, shuffle=True, collate_fn=multimodal_collate_fn, drop_last=True)
    va_ld = DataLoader(va_ds, batch_size=batch_size, shuffle=False, collate_fn=multimodal_collate_fn)
    model = model_cls(in_dim, n_types, n_results).to(DEVICE)
    crit_m, crit_a = EuclideanLoss(), MaskedSeqEuclideanLoss()
    opt = optim.Adam(model.parameters(), lr=lr)
    best = float('inf')
    for ep in range(epochs):
        model.train()
        for batch in tr_ld:
            imgs, cont, cat, lengths, target, aux_t = [b.to(DEVICE) for b in batch]
            opt.zero_grad()
            pred, aux_pred = model(imgs, cont, cat, lengths)
            loss = crit_m(pred, target) + aux_weight * crit_a(aux_pred, aux_t, lengths)
            loss.backward(); opt.step()
        model.eval(); dists=[]
        with torch.no_grad():
            for batch in va_ld:
                imgs, cont, cat, lengths, target, aux_t = [b.to(DEVICE) for b in batch]
                pred,_ = model(imgs, cont, cat, lengths)
                pr = pred.cpu().numpy()*np.array([105.,68.]); tg = target.cpu().numpy()*np.array([105.,68.])
                dists.extend(np.sqrt(np.sum((pr-tg)**2, axis=1)))
        md = float(np.mean(dists)); best = min(best, md)
    return best

print('Running ablation (1-fold, 20 epochs each)...')
res = {}
res['Full (CrossAttn + Aux)']   = train_one_fold(MultiModalNetV8, aux_weight=0.5)
res['No-Aux (aux_w=0)']         = train_one_fold(MultiModalNetV8, aux_weight=0.0)
res['No-CrossAttn']             = train_one_fold(MultiModalNet_NoCross, aux_weight=0.5)

import pandas as pd
df = pd.DataFrame([{'variant':k, 'val_dist(m)':round(v,3)} for k,v in res.items()])
print('\n========== Ablation (lower = better) ==========')
print(df.to_string(index=False))
base = res['Full (CrossAttn + Aux)']
print('\n기여도 (Full 대비 오차 증가량):')
for k,v in res.items():
    if k!='Full (CrossAttn + Aux)':
        print(f'  - {k} 제거 시: {v-base:+.3f} m')
# Out:
# Running ablation (1-fold, 20 epochs each)...
# Pre-rendering 13827 images (Cache Enabled)...
# Caching Images: 100%|██████████| 13827/13827 [00:00<00:00, 16259.51it/s]
# Pre-rendering 1601 images (Cache Enabled)...
# Caching Images: 100%|██████████| 1601/1601 [00:00<00:00, 16099.57it/s]
# Pre-rendering 13827 images (Cache Enabled)...
# Caching Images: 100%|██████████| 13827/13827 [00:00<00:00, 15478.60it/s]
# Pre-rendering 1601 images (Cache Enabled)...
# Caching Images: 100%|██████████| 1601/1601 [00:00<00:00, 16800.05it/s]
# Pre-rendering 13827 images (Cache Enabled)...
# Caching Images: 100%|██████████| 13827/13827 [00:00<00:00, 15330.07it/s]
# Pre-rendering 1601 images (Cache Enabled)...
# Caching Images: 100%|██████████| 1601/1601 [00:00<00:00, 17387.98it/s]
# ========== Ablation (lower = better) ==========
#                variant  val_dist(m)
# Full (CrossAttn + Aux)       14.173
#       No-Aux (aux_w=0)       14.269
#           No-CrossAttn       14.914
#
# 기여도 (Full 대비 오차 증가량):
#   - No-Aux (aux_w=0) 제거 시: +0.096 m
#   - No-CrossAttn 제거 시: +0.741 m
